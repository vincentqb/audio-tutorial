# %%
import cProfile

pr = cProfile.Profile()
pr.enable()

# %% [markdown]
# [example](https://github.com/LearnedVector/Wav2Letter/blob/master/Google%20Speech%20Command%20Example.ipynb)

# %%
import torch
import torchaudio
from torchaudio.datasets import SPEECHCOMMANDS

# %%
torchaudio.set_audio_backend("soundfile")

# %%
labels = [
        '-', '*',
        "backward",
        "bed",
        "bird",
        "cat",
        "dog",
        "down",
        "eight",
        "five",
        "follow",
        "forward",
        "four",
        "go",
        "happy",
        "house",
        "learn",
        "left",
        "marvin",
        "nine",
        "no",
        "off",
        "on",
        "one",
        "right",
        "seven",
        "sheila",
        "six",
        "stop",
        "three",
        "tree",
        "two",
        "up",
        "visual",
        "wow",
        "yes",
        "zero",
]

import collections


def build_mapping(labels):
    labels = list(collections.OrderedDict.fromkeys(list("".join(labels))))
    enumerated = list(enumerate(labels))
    flipped = [(sub[1], sub[0]) for sub in enumerated]

    d1 = collections.OrderedDict(enumerated)
    d2 = collections.OrderedDict(flipped)
    return {**d1, **d2}

def padding(l, max_length, fillwith):
    return l  + [fillwith] * (max_length-len(l))

def map_with_dict(mapping, l):
    return [mapping[t] for t in l]

def apply_with_padding(l, mapping, max_length, fillwith):
    l = map_with_dict(mapping, l)
    l = padding(l, max_length, mapping["*"])
    return l


test = "house"
max_length = max(map(len, labels))
vocab_size = len(labels) + 2

mapping = build_mapping(labels)

# test = apply(mapping, test)
# test = padding(test, max_length, mapping["*"])

encode = lambda l: apply_with_padding(l, mapping, max_length, mapping["*"])
decode = lambda l: apply_with_padding(l, mapping, max_length, mapping[1])

decode(encode(test))
# Out:
# ['h', 'o', 'u', 's', 'e', '*', '*', '*']

# %%
from torchaudio.transforms import MFCC

num_features = 13

melkwargs = {
    'n_fft': 512,
    'n_mels': 20,
    'hop_length': 80,
}

mfcc = MFCC(sample_rate=16000, n_mfcc=num_features, melkwargs=melkwargs)

# audio, self.sr, window_stride=(160, 80),
# fft_size=512, num_filt=20, num_coeffs=13

def process_waveform(waveform):
    # pick first channel, apply mfcc, tranpose for pad_sequence
    return mfcc(waveform)[0, ...].transpose(0, -1)

def process_target(target):

    # targets = []
    # for b in batch:
    #     if b:
    #         token = sp.encode_as_pieces(b[2])
    #         print(len(token))
    #         token = " ".join(token)
    #         targets.append(token)

    # return " ".join(sp.encode_as_ids(target))
    
    # return torch.IntTensor(sp.encode_as_ids(target))
    # print(target)
    return torch.IntTensor(encode(target))

# %%
class PROCESSED_SPEECHCOMMANDS(SPEECHCOMMANDS):
    def __getitem__(self, n):
        return self._process(super().__getitem__(n))
        
    def _process(self, item):
        # waveform, sample_rate, label, speaker_id, utterance_number
        waveform = process_waveform(item[0])
        label = process_target(item[2])
        return waveform, label

    def __next__(self):
        return self._process(super().__next__())

# %%
class MemoryCache(torch.utils.data.Dataset):
    """
    Wrap a dataset so that, whenever a new item is returned, it is saved to disk.
    """
                                                      
    def __init__(self, dataset):
        self.dataset = dataset                                                   
        self._id = id(self)                         
        self._cache = [None] * len(dataset)
                                  
    def __getitem__(self, n):      
        if self._cache[n]:                             
            return self._cache[n]          
                               
        item = self.dataset[n]          
        self._cache[n] = item             
                                          
        return item                       
                                  
    def __len__(self):                 
        return len(self.dataset)

# %%
#     waveform, sample_rate, label, speaker_id, utterance_number

def datasets():

    download = True
    root = "./"

    dataset = PROCESSED_SPEECHCOMMANDS(root, download=download)
    dataset = MemoryCache(dataset)

    return dataset

# %%
train = datasets()

# %%
from torch.utils.data import DataLoader
from random import randint



def collate_fn(batch):

    tensors = [b[0] for b in batch if b]
    targets = [b[1] for b in batch if b]

    # tensors = [process_waveform(b[0]) for b in batch if b]
    # targets = [process_target(b[2]) for b in batch if b]

    # truncate tensor list
    # length = 2**10
    # a = max(0, min([tensor.shape[-1] for tensor in tensors]) - length)
    # m = randint(0, a)
    # n = m + length
    # tensors = [t[..., m:n] for t in tensors]
    
    input_lengths = [t.shape[0] for t in tensors]
    target_lengths = [len(t) for t in targets]

    targets = torch.nn.utils.rnn.pad_sequence(targets, batch_first=True)
    tensors = torch.nn.utils.rnn.pad_sequence(tensors, batch_first=True)
    tensors = tensors.transpose(1, -1)
    return tensors, targets, input_lengths, target_lengths


batch_size = 128  # max number of sentences per batch
loader_train = DataLoader(train, batch_size=batch_size, collate_fn=collate_fn, shuffle=True)

# %%
#     waveform, sample_rate, label, speaker_id, utterance_number

def datasets():

    download = True
    root = "./"

    dataset = SPEECHCOMMANDS(root, download=download)

    return dataset

train = datasets()

# %%
from torch import nn


class PrintLayer(nn.Module):
    def __init__(self):
        super(PrintLayer, self).__init__()
    
    def forward(self, x):
        # Do your print / debug stuff here
        print(x)
        return x
    
    

class Wav2Letter(nn.Module):
    """Wav2Letter Speech Recognition model
        Architecture is based off of Facebooks AI Research paper
        https://arxiv.org/pdf/1609.03193.pdf
        This specific architecture accepts mfcc or
        power spectrums speech signals
        TODO: use cuda if available
        Args:
            num_features (int): number of mfcc features
            num_classes (int): number of unique grapheme class labels
    """

    def __init__(self, num_features, num_classes):
        super(Wav2Letter, self).__init__()

        # Conv1d(in_channels, out_channels, kernel_size, stride)
        self.layers = nn.Sequential(
            # PrintLayer(),
            nn.Conv1d(num_features, 250, 48, 2),
            nn.ReLU(),
            nn.Conv1d(250, 250, 7),
            nn.ReLU(),
            nn.Conv1d(250, 250, 7),
            nn.ReLU(),
            nn.Conv1d(250, 250, 7),
            nn.ReLU(),
            nn.Conv1d(250, 250, 7),
            nn.ReLU(),
            # nn.Conv1d(250, 250, 7),
            # nn.ReLU(),
            # nn.Conv1d(250, 250, 7),
            # nn.ReLU(),
            nn.Conv1d(250, 250, 7),
            nn.ReLU(),
            nn.Conv1d(250, 2000, 32),
            nn.ReLU(),
            nn.Conv1d(2000, 2000, 1),
            nn.ReLU(),
            nn.Conv1d(2000, num_classes, 1),
        )

    def forward(self, batch):
        """Forward pass through Wav2Letter network than 
            takes log probability of output
        Args:
            batch (int): mini batch of data
             shape (batch, num_features, frame_len)
        Returns:
            log_probs (torch.Tensor):
                shape  (batch_size, num_classes, output_len)
        """
        # y_pred shape (batch_size, num_classes, output_len)
        y_pred = self.layers(batch)

        # compute log softmax probability on graphemes
        log_probs = nn.functional.log_softmax(y_pred, dim=1)

        return log_probs


model = Wav2Letter(num_features, vocab_size)

# %%
import torchaudio
from torch.optim import Adadelta

model = Wav2Letter(num_features, vocab_size)

optimizer_params = {
    "lr": 1.0,
    "eps": 1e-8,
    "rho": 0.95,
}
optimizer = Adadelta(model.parameters(), **optimizer_params)

max_epoch = 10
clip_norm = 10.

criterion = torch.nn.CTCLoss()

max_files = 100

from tqdm import tqdm

for epoch in range(max_epoch):
    # print(epoch)
    
    i_files = 0
    for inputs, targets, _, target_lengths in tqdm(loader_train):
        
        if i_files > max_files:
            break

        if inputs is None or targets is None:
            continue

        # print("input", inputs.shape)
        outputs = model(inputs)
        # (input length, batch size, number of classes)
        # input_lengths = [len(o) for o in outputs]

        outputs = outputs.transpose(1, 2).transpose(0, 1)
        # print("output", outputs.shape)
        # print("target", targets.shape)
        
        # print(inputs.shape)
        # print(outputs.shape)
        # print(targets.shape)
        # print(len(targets))
        # print(targets.shape)
        # print(input_lengths)
        # input_lengths = [len(o) for o in outputs]
        # print(len(input_lengths))
        # target_lengths = [len(t) for t in targets]
        # print(target_lengths)
        # ctc_loss(input, target, input_lengths, target_lengths)

        # input_lengths = [outputs.shape[0]] * outputs.shape[1]
        
        # CTC arguments
        # https://pytorch.org/docs/master/nn.html#torch.nn.CTCLoss
        # better definitions for ctc arguments
        # https://discuss.pytorch.org/t/ctcloss-with-warp-ctc-help/8788/3
        mini_batch_size = len(inputs)
        
        input_lengths = torch.full((mini_batch_size,), outputs.shape[0], dtype=torch.long)
        target_lengths = torch.IntTensor([target.shape[0] for target in targets])
        
        # print(torch.isnan(outputs).any())
        # print(torch.isnan(targets).any())
        # print(torch.isnan(input_lengths).any())
        # print(torch.isnan(target_lengths).any())
        # print(outputs.shape)
        # print(targets.shape)
        # print(input_lengths.shape)
        # print(target_lengths.shape)

        # outputs: input length, batch size, number of classes (including blank) 
        # targets: batch size, max target length
        # input_lengths: batch size
        # target_lengths: batch size
        loss = criterion(outputs, targets, input_lengths, target_lengths)

        # print("stepping")
        optimizer.zero_grad()
        loss.backward()
        # torch.nn.utils.clip_grad_norm_(model.parameters(), clip_norm)
        optimizer.step()
        
        i_files += 1
        
    print(epoch, loss)
# Out:
#  12%|█▏        | 101/827 [53:21<1:47:36,  8.89s/it]
#   0%|          | 0/827 [00:00<?, ?it/s]
# 0 tensor(2.8296, grad_fn=<MeanBackward0>)
#   0%|          | 1/827 [00:08<1:51:41,  8.11s/it]
#   0%|          | 2/827 [00:16<1:51:05,  8.08s/it]
#   0%|          | 3/827 [00:23<1:50:05,  8.02s/it]
#   0%|          | 4/827 [00:32<1:51:31,  8.13s/it]
#   1%|          | 5/827 [00:41<1:54:18,  8.34s/it]
#   1%|          | 6/827 [00:49<1:53:05,  8.26s/it]
#   1%|          | 7/827 [00:57<1:52:54,  8.26s/it]
#   1%|          | 8/827 [01:05<1:51:13,  8.15s/it]
#   1%|          | 9/827 [01:13<1:49:51,  8.06s/it]
#   1%|          | 10/827 [01:21<1:49:29,  8.04s/it]
#   1%|▏         | 11/827 [01:29<1:48:19,  7.97s/it]
#   1%|▏         | 12/827 [01:36<1:47:37,  7.92s/it]
#   2%|▏         | 13/827 [01:44<1:46:51,  7.88s/it]
#   2%|▏         | 14/827 [01:52<1:45:47,  7.81s/it]
#   2%|▏         | 15/827 [02:00<1:45:42,  7.81s/it]
#   2%|▏         | 16/827 [02:07<1:45:41,  7.82s/it]
#   2%|▏         | 17/827 [02:15<1:45:37,  7.82s/it]
#   2%|▏         | 18/827 [02:23<1:45:08,  7.80s/it]
#   2%|▏         | 19/827 [02:31<1:44:58,  7.79s/it]
#   2%|▏         | 20/827 [02:39<1:44:57,  7.80s/it]
#   3%|▎         | 21/827 [02:47<1:45:36,  7.86s/it]
#   3%|▎         | 22/827 [02:54<1:45:15,  7.85s/it]
#   3%|▎         | 23/827 [03:02<1:45:36,  7.88s/it]
#   3%|▎         | 24/827 [03:10<1:45:04,  7.85s/it]
#   3%|▎         | 25/827 [03:18<1:44:20,  7.81s/it]
#   3%|▎         | 26/827 [03:26<1:43:51,  7.78s/it]
#   3%|▎         | 27/827 [03:33<1:43:47,  7.78s/it]
#   3%|▎         | 28/827 [03:41<1:43:42,  7.79s/it]
#   4%|▎         | 29/827 [03:49<1:43:01,  7.75s/it]
#   4%|▎         | 30/827 [03:57<1:42:56,  7.75s/it]
#   4%|▎         | 31/827 [04:04<1:42:53,  7.76s/it]
#   4%|▍         | 32/827 [04:12<1:42:06,  7.71s/it]
#   4%|▍         | 33/827 [04:20<1:42:00,  7.71s/it]
#   4%|▍         | 34/827 [04:27<1:41:47,  7.70s/it]
#   4%|▍         | 35/827 [04:35<1:42:10,  7.74s/it]
#   4%|▍         | 36/827 [04:43<1:42:18,  7.76s/it]
#   4%|▍         | 37/827 [04:51<1:42:21,  7.77s/it]
#   5%|▍         | 38/827 [04:59<1:42:04,  7.76s/it]
#   5%|▍         | 39/827 [05:06<1:42:05,  7.77s/it]
#   5%|▍         | 40/827 [05:14<1:41:52,  7.77s/it]
#   5%|▍         | 41/827 [05:22<1:41:19,  7.73s/it]
#   5%|▌         | 42/827 [05:30<1:41:51,  7.79s/it]
#   5%|▌         | 43/827 [05:37<1:41:03,  7.73s/it]
#   5%|▌         | 44/827 [05:45<1:40:56,  7.73s/it]
#   5%|▌         | 45/827 [05:53<1:41:11,  7.76s/it]
#   6%|▌         | 46/827 [06:01<1:41:01,  7.76s/it]
#   6%|▌         | 47/827 [06:09<1:42:09,  7.86s/it]
#   6%|▌         | 48/827 [06:16<1:41:41,  7.83s/it]
#   6%|▌         | 49/827 [06:24<1:41:32,  7.83s/it]
#   6%|▌         | 50/827 [06:32<1:41:22,  7.83s/it]
#   6%|▌         | 51/827 [06:40<1:41:07,  7.82s/it]
#   6%|▋         | 52/827 [06:48<1:40:42,  7.80s/it]
#   6%|▋         | 53/827 [06:56<1:41:49,  7.89s/it]
#   7%|▋         | 54/827 [07:04<1:41:01,  7.84s/it]
#   7%|▋         | 55/827 [07:12<1:41:45,  7.91s/it]
#   7%|▋         | 56/827 [07:20<1:42:23,  7.97s/it]
#   7%|▋         | 57/827 [07:28<1:42:06,  7.96s/it]
#   7%|▋         | 58/827 [07:36<1:43:31,  8.08s/it]
#   7%|▋         | 59/827 [07:44<1:43:52,  8.12s/it]
#   7%|▋         | 60/827 [07:52<1:42:40,  8.03s/it]
#   7%|▋         | 61/827 [08:00<1:42:27,  8.02s/it]
#   7%|▋         | 62/827 [08:09<1:45:34,  8.28s/it]
#   8%|▊         | 63/827 [08:17<1:45:36,  8.29s/it]
#   8%|▊         | 64/827 [08:25<1:44:47,  8.24s/it]
#   8%|▊         | 65/827 [08:33<1:44:14,  8.21s/it]
#   8%|▊         | 66/827 [08:42<1:43:26,  8.16s/it]
#   8%|▊         | 67/827 [08:49<1:42:07,  8.06s/it]
#   8%|▊         | 68/827 [08:57<1:41:45,  8.04s/it]
#   8%|▊         | 69/827 [09:05<1:40:50,  7.98s/it]
#   8%|▊         | 70/827 [09:13<1:39:56,  7.92s/it]
#   9%|▊         | 71/827 [09:21<1:39:27,  7.89s/it]
#   9%|▊         | 72/827 [09:28<1:38:35,  7.84s/it]
#   9%|▉         | 73/827 [09:36<1:38:40,  7.85s/it]
#   9%|▉         | 74/827 [09:44<1:38:41,  7.86s/it]
#   9%|▉         | 75/827 [09:52<1:38:06,  7.83s/it]
#   9%|▉         | 76/827 [10:00<1:38:07,  7.84s/it]
#   9%|▉         | 77/827 [10:08<1:37:19,  7.79s/it]
#   9%|▉         | 78/827 [10:15<1:36:57,  7.77s/it]
#  10%|▉         | 79/827 [10:23<1:36:09,  7.71s/it]
#  10%|▉         | 80/827 [10:31<1:36:35,  7.76s/it]
#  10%|▉         | 81/827 [10:38<1:36:28,  7.76s/it]
#  10%|▉         | 82/827 [10:46<1:36:03,  7.74s/it]
#  10%|█         | 83/827 [10:54<1:36:12,  7.76s/it]
#  10%|█         | 84/827 [11:02<1:36:25,  7.79s/it]
#  10%|█         | 85/827 [11:09<1:35:32,  7.73s/it]
#  10%|█         | 86/827 [11:17<1:35:18,  7.72s/it]
#  11%|█         | 87/827 [11:25<1:35:10,  7.72s/it]
#  11%|█         | 88/827 [11:33<1:35:32,  7.76s/it]
#  11%|█         | 89/827 [11:40<1:35:16,  7.75s/it]
#  11%|█         | 90/827 [11:48<1:34:34,  7.70s/it]
#  11%|█         | 91/827 [11:56<1:34:54,  7.74s/it]
#  11%|█         | 92/827 [12:04<1:34:47,  7.74s/it]
#  11%|█         | 93/827 [12:11<1:34:48,  7.75s/it]
#  11%|█▏        | 94/827 [12:19<1:34:37,  7.75s/it]
#  11%|█▏        | 95/827 [12:27<1:34:31,  7.75s/it]
#  12%|█▏        | 96/827 [12:35<1:34:46,  7.78s/it]
#  12%|█▏        | 97/827 [12:42<1:34:06,  7.73s/it]
#  12%|█▏        | 98/827 [12:50<1:34:07,  7.75s/it]
#  12%|█▏        | 99/827 [12:58<1:33:39,  7.72s/it]
#  12%|█▏        | 100/827 [13:06<1:33:44,  7.74s/it]
#  12%|█▏        | 101/827 [13:13<1:33:50,  7.75s/it]
#
#   0%|          | 0/827 [00:00<?, ?it/s]
# 1 tensor(2.5557, grad_fn=<MeanBackward0>)
#   0%|          | 1/827 [00:07<1:43:51,  7.54s/it]
#
#   0%|          | 2/827 [00:15<1:44:48,  7.62s/it]
#
#   0%|          | 3/827 [00:22<1:44:37,  7.62s/it]
#
#   0%|          | 4/827 [00:30<1:44:20,  7.61s/it]
#
#   1%|          | 5/827 [00:38<1:43:43,  7.57s/it]
#
#   1%|          | 6/827 [00:45<1:45:06,  7.68s/it]
#
#   1%|          | 7/827 [00:54<1:48:57,  7.97s/it]
#
#   1%|          | 8/827 [01:02<1:47:37,  7.88s/it]
#
#   1%|          | 9/827 [01:10<1:50:45,  8.12s/it]
#
#   1%|          | 10/827 [01:18<1:49:12,  8.02s/it]
#
#   1%|▏         | 11/827 [01:27<1:50:38,  8.14s/it]
#
#   1%|▏         | 12/827 [01:35<1:50:17,  8.12s/it]
#
#   2%|▏         | 13/827 [01:46<2:04:36,  9.18s/it]
#
#   2%|▏         | 14/827 [01:55<2:00:56,  8.92s/it]
#
#   2%|▏         | 15/827 [02:03<1:57:27,  8.68s/it]
#
#   2%|▏         | 16/827 [02:11<1:54:13,  8.45s/it]
#
#   2%|▏         | 17/827 [02:19<1:53:53,  8.44s/it]
#
#   2%|▏         | 18/827 [02:27<1:52:29,  8.34s/it]
#
#   2%|▏         | 19/827 [02:35<1:51:07,  8.25s/it]
#
#   2%|▏         | 20/827 [02:43<1:50:20,  8.20s/it]
#
#   3%|▎         | 21/827 [02:51<1:49:07,  8.12s/it]
#
#   3%|▎         | 22/827 [03:00<1:49:06,  8.13s/it]
#
#   3%|▎         | 23/827 [03:08<1:48:59,  8.13s/it]
#
#   3%|▎         | 24/827 [03:16<1:48:34,  8.11s/it]
#
#   3%|▎         | 25/827 [03:24<1:47:19,  8.03s/it]
#
#   3%|▎         | 26/827 [03:31<1:46:41,  7.99s/it]
#
#   3%|▎         | 27/827 [03:39<1:46:31,  7.99s/it]
#
#   3%|▎         | 28/827 [03:47<1:46:14,  7.98s/it]
#
#   4%|▎         | 29/827 [03:55<1:45:38,  7.94s/it]
#
#   4%|▎         | 30/827 [04:03<1:45:27,  7.94s/it]
#
#   4%|▎         | 31/827 [04:12<1:47:15,  8.09s/it]
#
#   4%|▍         | 32/827 [04:20<1:48:02,  8.15s/it]
#
#   4%|▍         | 33/827 [04:28<1:46:39,  8.06s/it]
#
#   4%|▍         | 34/827 [04:35<1:44:37,  7.92s/it]
#
#   4%|▍         | 35/827 [04:43<1:43:55,  7.87s/it]
#
#   4%|▍         | 36/827 [04:51<1:43:39,  7.86s/it]
#
#   4%|▍         | 37/827 [04:59<1:43:07,  7.83s/it]
#
#   5%|▍         | 38/827 [05:07<1:43:21,  7.86s/it]
#
#   5%|▍         | 39/827 [05:14<1:42:39,  7.82s/it]
#
#   5%|▍         | 40/827 [05:22<1:43:37,  7.90s/it]
#
#   5%|▍         | 41/827 [05:30<1:42:58,  7.86s/it]
#
#   5%|▌         | 42/827 [05:38<1:43:00,  7.87s/it]
#
#   5%|▌         | 43/827 [05:46<1:43:35,  7.93s/it]
#
#   5%|▌         | 44/827 [05:54<1:42:25,  7.85s/it]
#
#   5%|▌         | 45/827 [06:02<1:42:39,  7.88s/it]
#
#   6%|▌         | 46/827 [06:10<1:41:56,  7.83s/it]
#
#   6%|▌         | 47/827 [06:18<1:42:30,  7.89s/it]
#
#   6%|▌         | 48/827 [06:25<1:40:29,  7.74s/it]
#
#   6%|▌         | 49/827 [06:33<1:39:59,  7.71s/it]
#
#   6%|▌         | 50/827 [06:41<1:41:34,  7.84s/it]
#
#   6%|▌         | 51/827 [06:48<1:40:42,  7.79s/it]
#
#   6%|▋         | 52/827 [06:56<1:39:46,  7.72s/it]
#
#   6%|▋         | 53/827 [07:04<1:39:22,  7.70s/it]
#
#   7%|▋         | 54/827 [07:11<1:39:28,  7.72s/it]
#
#   7%|▋         | 55/827 [07:19<1:40:13,  7.79s/it]
#
#   7%|▋         | 56/827 [07:27<1:40:11,  7.80s/it]
#
#   7%|▋         | 57/827 [07:35<1:39:18,  7.74s/it]
#
#   7%|▋         | 58/827 [07:43<1:39:22,  7.75s/it]
#
#   7%|▋         | 59/827 [07:50<1:39:04,  7.74s/it]
#
#   7%|▋         | 60/827 [07:58<1:37:56,  7.66s/it]
#
#   7%|▋         | 61/827 [08:05<1:37:00,  7.60s/it]
#
#   7%|▋         | 62/827 [08:13<1:36:58,  7.61s/it]
#
#   8%|▊         | 63/827 [08:20<1:37:11,  7.63s/it]
#
#   8%|▊         | 64/827 [08:28<1:36:50,  7.62s/it]
#
#   8%|▊         | 65/827 [08:36<1:36:27,  7.60s/it]
#
#   8%|▊         | 66/827 [08:43<1:36:23,  7.60s/it]
#
#   8%|▊         | 67/827 [08:51<1:36:42,  7.63s/it]
#
#   8%|▊         | 68/827 [08:59<1:36:30,  7.63s/it]
#
#   8%|▊         | 69/827 [09:06<1:35:52,  7.59s/it]
#
#   8%|▊         | 70/827 [09:14<1:35:36,  7.58s/it]
#
#   9%|▊         | 71/827 [09:21<1:35:45,  7.60s/it]
#
#   9%|▊         | 72/827 [09:29<1:35:32,  7.59s/it]
#
#   9%|▉         | 73/827 [09:36<1:34:45,  7.54s/it]
#
#   9%|▉         | 74/827 [09:44<1:34:39,  7.54s/it]
#
#   9%|▉         | 75/827 [09:51<1:34:23,  7.53s/it]
#
#   9%|▉         | 76/827 [09:59<1:34:19,  7.54s/it]
#
#   9%|▉         | 77/827 [10:06<1:34:19,  7.55s/it]
#
#   9%|▉         | 78/827 [10:14<1:34:29,  7.57s/it]
#
#  10%|▉         | 79/827 [10:22<1:35:10,  7.63s/it]
#
#  10%|▉         | 80/827 [10:30<1:36:23,  7.74s/it]
#
#  10%|▉         | 81/827 [10:38<1:36:55,  7.80s/it]
#
#  10%|▉         | 82/827 [10:45<1:36:42,  7.79s/it]
#
#  10%|█         | 83/827 [10:53<1:37:03,  7.83s/it]
#
#  10%|█         | 84/827 [11:01<1:36:55,  7.83s/it]
#
#  10%|█         | 85/827 [11:09<1:36:00,  7.76s/it]
#
#  10%|█         | 86/827 [11:16<1:35:03,  7.70s/it]
#
#  11%|█         | 87/827 [11:24<1:34:40,  7.68s/it]
#
#  11%|█         | 88/827 [11:32<1:34:02,  7.64s/it]
#
#  11%|█         | 89/827 [11:39<1:34:27,  7.68s/it]
#
#  11%|█         | 90/827 [11:47<1:34:18,  7.68s/it]
#
#  11%|█         | 91/827 [11:55<1:33:58,  7.66s/it]
#
#  11%|█         | 92/827 [12:02<1:33:44,  7.65s/it]
#
#  11%|█         | 93/827 [12:10<1:33:49,  7.67s/it]
#
#  11%|█▏        | 94/827 [12:18<1:34:04,  7.70s/it]
#
#  11%|█▏        | 95/827 [12:25<1:33:54,  7.70s/it]
#
#  12%|█▏        | 96/827 [12:33<1:33:09,  7.65s/it]
#
#  12%|█▏        | 97/827 [12:41<1:32:38,  7.61s/it]
#
#  12%|█▏        | 98/827 [12:48<1:33:34,  7.70s/it]
#
#  12%|█▏        | 99/827 [12:56<1:33:07,  7.68s/it]
#
#  12%|█▏        | 100/827 [13:04<1:32:48,  7.66s/it]
#
#  12%|█▏        | 101/827 [13:11<1:32:17,  7.63s/it]
#
#
#   0%|          | 0/827 [00:00<?, ?it/s]
# 2 tensor(2.5633, grad_fn=<MeanBackward0>)
#   0%|          | 1/827 [00:07<1:42:29,  7.45s/it]
#
#
#   0%|          | 2/827 [00:15<1:42:54,  7.48s/it]
#
#
#   0%|          | 3/827 [00:22<1:43:06,  7.51s/it]
#
#
#   0%|          | 4/827 [00:29<1:42:08,  7.45s/it]
#
#
#   1%|          | 5/827 [00:37<1:42:05,  7.45s/it]
#
#
#   1%|          | 6/827 [00:45<1:43:14,  7.54s/it]
#
#
#   1%|          | 7/827 [00:52<1:43:06,  7.54s/it]
#
#
#   1%|          | 8/827 [01:00<1:42:43,  7.53s/it]
#
#
#   1%|          | 9/827 [01:07<1:43:19,  7.58s/it]
#
#
#   1%|          | 10/827 [01:15<1:44:26,  7.67s/it]
#
#
#   1%|▏         | 11/827 [01:23<1:44:30,  7.68s/it]
#
#
#   1%|▏         | 12/827 [01:31<1:44:07,  7.67s/it]
#
#
#   2%|▏         | 13/827 [01:38<1:43:36,  7.64s/it]
#
#
#   2%|▏         | 14/827 [01:46<1:42:38,  7.58s/it]
#
#
#   2%|▏         | 15/827 [01:53<1:42:38,  7.58s/it]
#
#
#   2%|▏         | 16/827 [02:01<1:42:01,  7.55s/it]
#
#
#   2%|▏         | 17/827 [02:08<1:41:35,  7.52s/it]
#
#
#   2%|▏         | 18/827 [02:16<1:41:10,  7.50s/it]
#
#
#   2%|▏         | 19/827 [02:23<1:40:14,  7.44s/it]
#
#
#   2%|▏         | 20/827 [02:30<1:40:24,  7.47s/it]
#
#
#   3%|▎         | 21/827 [02:38<1:40:44,  7.50s/it]
#
#
#   3%|▎         | 22/827 [02:46<1:41:37,  7.57s/it]
#
#
#   3%|▎         | 23/827 [02:53<1:41:25,  7.57s/it]
#
#
#   3%|▎         | 24/827 [03:01<1:41:23,  7.58s/it]
#
#
#   3%|▎         | 25/827 [03:09<1:42:48,  7.69s/it]
#
#
#   3%|▎         | 26/827 [03:16<1:41:38,  7.61s/it]
#
#
#   3%|▎         | 27/827 [03:24<1:41:30,  7.61s/it]
#
#
#   3%|▎         | 28/827 [03:32<1:42:13,  7.68s/it]
#
#
#   4%|▎         | 29/827 [03:39<1:41:08,  7.60s/it]
#
#
#   4%|▎         | 30/827 [03:46<1:39:54,  7.52s/it]
#
#
#   4%|▎         | 31/827 [03:54<1:40:04,  7.54s/it]
#
#
#   4%|▍         | 32/827 [04:02<1:40:01,  7.55s/it]
#
#
#   4%|▍         | 33/827 [04:09<1:39:53,  7.55s/it]
#
#
#   4%|▍         | 34/827 [04:17<1:39:28,  7.53s/it]
#
#
#   4%|▍         | 35/827 [04:24<1:39:18,  7.52s/it]
#
#
#   4%|▍         | 36/827 [04:32<1:38:54,  7.50s/it]
#
#
#   4%|▍         | 37/827 [04:39<1:39:13,  7.54s/it]
#
#
#   5%|▍         | 38/827 [04:47<1:39:29,  7.57s/it]
#
#
#   5%|▍         | 39/827 [04:54<1:39:42,  7.59s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-711c285a935b> in <module>
#      24
#      25     i_files = 0
# ---> 26     for inputs, targets, _, target_lengths in tqdm(loader_train):
#      27
#      28         if i_files > max_files:
#
# ~/anaconda3/envs/pyspeech/lib/python3.7/site-packages/tqdm/std.py in __iter__(self)
#    1105                 fp_write=getattr(self.fp, 'write', sys.stderr.write))
#    1106
# -> 1107         for obj in iterable:
#    1108             yield obj
#    1109             # Update and possibly print the progressbar.
#
# ~/anaconda3/envs/pyspeech/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/envs/pyspeech/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     383     def _next_data(self):
#     384         index = self._next_index()  # may raise StopIteration
# --> 385         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     386         if self._pin_memory:
#     387             data = _utils.pin_memory.pin_memory(data)
#
# ~/anaconda3/envs/pyspeech/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/anaconda3/envs/pyspeech/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# <ipython-input-7-310bd55dac72> in __getitem__(self, n)
#      13             return self._cache[n]
#      14
# ---> 15         item = self.dataset[n]
#      16         self._cache[n] = item
#      17
#
# <ipython-input-6-ea6777c124d4> in __getitem__(self, n)
#       1 class PROCESSED_SPEECHCOMMANDS(SPEECHCOMMANDS):
#       2     def __getitem__(self, n):
# ----> 3         return self._process(super().__getitem__(n))
#       4
#       5     def _process(self, item):
#
# <ipython-input-6-ea6777c124d4> in _process(self, item)
#       5     def _process(self, item):
#       6         # waveform, sample_rate, label, speaker_id, utterance_number
# ----> 7         waveform = process_waveform(item[0])
#       8         label = process_target(item[2])
#       9         return waveform, label
#
# <ipython-input-5-c2b4fd6ccfde> in process_waveform(waveform)
#      16 def process_waveform(waveform):
#      17     # pick first channel, apply mfcc, tranpose for pad_sequence
# ---> 18     return mfcc(waveform)[0, ...].transpose(0, -1)
#      19
#      20 def process_target(target):
#
# ~/anaconda3/envs/pyspeech/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/pyspeech/lib/python3.7/site-packages/torchaudio-0.5.0a0+12ea313-py3.7-macosx-10.9-x86_64.egg/torchaudio/transforms.py in forward(self, waveform)
#     352         waveform = waveform.view(-1, shape[-1])
#     353
# --> 354         mel_specgram = self.MelSpectrogram(waveform)
#     355         if self.log_mels:
#     356             log_offset = 1e-6
#
# ~/anaconda3/envs/pyspeech/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/pyspeech/lib/python3.7/site-packages/torchaudio-0.5.0a0+12ea313-py3.7-macosx-10.9-x86_64.egg/torchaudio/transforms.py in forward(self, waveform)
#     288             torch.Tensor: Mel frequency spectrogram of size (..., ``n_mels``, time)
#     289         """
# --> 290         specgram = self.spectrogram(waveform)
#     291         mel_specgram = self.mel_scale(specgram)
#     292         return mel_specgram
#
# ~/anaconda3/envs/pyspeech/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/pyspeech/lib/python3.7/site-packages/torchaudio-0.5.0a0+12ea313-py3.7-macosx-10.9-x86_64.egg/torchaudio/transforms.py in forward(self, waveform)
#      71         """
#      72         return F.spectrogram(waveform, self.pad, self.window, self.n_fft, self.hop_length,
# ---> 73                              self.win_length, self.power, self.normalized)
#      74
#      75
#
# ~/anaconda3/envs/pyspeech/lib/python3.7/site-packages/torchaudio-0.5.0a0+12ea313-py3.7-macosx-10.9-x86_64.egg/torchaudio/functional.py in spectrogram(waveform, pad, window, n_fft, hop_length, win_length, power, normalized)
#     267         spec_f /= window.pow(2.).sum().sqrt()
#     268     if power is not None:
# --> 269         spec_f = complex_norm(spec_f, power=power)
#     270
#     271     return spec_f
#
# ~/anaconda3/envs/pyspeech/lib/python3.7/site-packages/torchaudio-0.5.0a0+12ea313-py3.7-macosx-10.9-x86_64.egg/torchaudio/functional.py in complex_norm(complex_tensor, power)
#     527     if power == 1.0:
#     528         return torch.norm(complex_tensor, 2, -1)
# --> 529     return torch.norm(complex_tensor, 2, -1).pow(power)
#     530
#     531
#
# ~/anaconda3/envs/pyspeech/lib/python3.7/site-packages/torch/functional.py in norm(input, p, dim, keepdim, out, dtype)
#     767             dim = tuple(range(ndim))
#     768         if out is None and dtype is None:
# --> 769             return torch._C._VariableFunctions.norm(input, p, dim, keepdim=keepdim)
#     770         elif out is None:
#     771             return torch._C._VariableFunctions.norm(input, p, dim, keepdim=keepdim, dtype=dtype)
#
# KeyboardInterrupt:

# %%
from torch import topk

def GreedyDecoder(ctc_matrix, blank_label=0):
    """Greedy Decoder. Returns highest probability of
        class labels for each timestep
        # TODO: collapse blank labels
    Args:
        ctc_matrix (torch.Tensor): 
            shape (1, num_classes, output_len)
        blank_label (int): blank labels to collapse
    
    Returns:
        torch.Tensor: class labels per time step.
         shape (ctc timesteps)
    """
    _, indices = topk(ctc_matrix, k=1, dim=1)
    return indices[:, 0, :]

# %%
output[0, 0, :]
# Out:
# tensor([-0.7700, -0.7678, -0.7659, -0.7641, -0.7627, -0.7614, -0.7602, -0.7592,
#         -0.7584, -0.7579, -0.7575, -0.7571, -0.7568, -0.7573, -0.7576, -0.7583],
#        grad_fn=<SliceBackward>)

# %%
sample = inputs[0].unsqueeze(0)
target = targets[0]

print(decode(targets[0].tolist()))

output = model(sample)
print(output.shape)

greedy_output = GreedyDecoder(output)

print(greedy_output.shape)
print(greedy_output)
print(decode(greedy_output.tolist()[0]))
# Out:
# ['o', 'n', '*', '*', '*', '*', '*', '*']
# torch.Size([1, 39, 16])
# torch.Size([1, 16])
# tensor([[9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9]])
# ['e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e']

# %%
pr.disable()
pr.print_stats(sort='time')
# Out:
#          15923535 function calls (15545921 primitive calls) in 5101.043 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       342 2324.966    6.798 2324.966    6.798 {method 'run_backward' of 'torch._C._EngineBase' objects}
#      3087 2126.677    0.689 2126.677    0.689 {built-in method conv1d}
#     37883  502.738    0.013  502.738    0.013 {built-in method norm}
#     12312   23.398    0.002   23.398    0.002 {method 'add' of 'torch._C._TensorBase' objects}
#     37883   14.301    0.000   14.800    0.000 soundfile.py:1314(_cdata_io)
#     37883   14.047    0.000   15.030    0.000 soundfile.py:1160(_open)
#        20   10.930    0.546   10.930    0.546 {method 'control' of 'select.kqueue' objects}
#     18468    8.064    0.000    8.064    0.000 {method 'mul_' of 'torch._C._TensorBase' objects}
#     12312    6.508    0.001    6.508    0.001 {method 'addcmul_' of 'torch._C._TensorBase' objects}
#       342    6.201    0.018   55.031    0.161 adadelta.py:38(step)
#     75764    5.760    0.000    5.760    0.000 {built-in method matmul}
#     37883    5.594    0.000    5.594    0.000 {built-in method stft}
#     12312    4.780    0.000    4.780    0.000 {method 'sqrt_' of 'torch._C._TensorBase' objects}
#      6156    3.257    0.001    3.257    0.001 {method 'add_' of 'torch._C._TensorBase' objects}
#      2744    3.153    0.001    3.153    0.001 {built-in method relu}
#      6156    2.762    0.000    2.762    0.000 {method 'div_' of 'torch._C._TensorBase' objects}
#     75792    2.607    0.000    2.607    0.000 {built-in method posix.getcwd}
#      6138    2.506    0.000    2.506    0.000 {method 'zero_' of 'torch._C._TensorBase' objects}
#     78330    1.878    0.000    1.878    0.000 {built-in method posix.stat}
# 196272/38568    1.551    0.000 2658.923    0.069 module.py:522(__call__)
#    303061    1.501    0.000    1.501    0.000 {method 'view' of 'torch._C._TensorBase' objects}
#     37882    1.310    0.000    3.918    0.000 functional.py:371(amplitude_to_DB)
#     37882    1.164    0.000    1.164    0.000 {built-in method clamp}
#     37883    1.091    0.000  572.768    0.015 <ipython-input-6-ea6777c124d4>:2(__getitem__)
#     37882    1.010    0.000    1.010    0.000 {method 'pow' of 'torch._C._TensorBase' objects}
#     37883    0.813    0.000    0.813    0.000 {built-in method torch._C._nn.reflection_pad1d}
#    190439    0.776    0.000    0.776    0.000 {method 'transpose' of 'torch._C._TensorBase' objects}
#     37882    0.712    0.000    0.712    0.000 {built-in method log10}
#     37883    0.651    0.000   16.040    0.000 soundfile.py:1301(_array_io)
#     37883    0.628    0.000  528.112    0.014 transforms.py:341(forward)
#       690    0.617    0.001    0.745    0.001 rnn.py:288(pad_sequence)
#    336818    0.573    0.000    0.864    0.000 posixpath.py:75(join)
#     37883    0.561    0.000  504.404    0.013 functional.py:516(complex_norm)
#     37883    0.545    0.000  512.718    0.014 functional.py:225(spectrogram)
#     37882    0.533    0.000    6.013    0.000 transforms.py:207(forward)
# 212875/64    0.460    0.000 5090.095   79.533 {built-in method builtins.next}
#     75766    0.443    0.000    0.580    0.000 soundfile.py:1151(close)
#      8096    0.428    0.000    0.428    0.000 {method 'acquire' of '_thread.lock' objects}
#     37882    0.422    0.000    0.691    0.000 <ipython-input-5-c2b4fd6ccfde>:20(process_target)
#     37883    0.394    0.000    7.242    0.000 functional.py:302(stft)
#     77955    0.390    0.000    0.597    0.000 posixpath.py:338(normpath)
#    151532    0.368    0.000    0.569    0.000 soundfile.py:735(seek)
#     37885    0.366    0.000    0.366    0.000 {method 'max' of 'torch._C._TensorBase' objects}
#     37883    0.363    0.000    0.363    0.000 {built-in method from_numpy}
#     37882    0.352    0.000    0.385    0.000 __init__.py:1658(__getattr__)
#     37883    0.349    0.000   36.589    0.001 _soundfile_backend.py:49(load)
#     37883    0.339    0.000   16.471    0.000 soundfile.py:527(__init__)
#    309734    0.326    0.000    0.326    0.000 module.py:562(__getattr__)
#     37883    0.314    0.000  528.849    0.014 <ipython-input-5-c2b4fd6ccfde>:16(process_waveform)
#     37883    0.290    0.000    4.710    0.000 posixpath.py:453(relpath)
#     37884    0.279    0.000    0.279    0.000 {built-in method numpy.empty}
#        36    0.262    0.007    0.262    0.007 {method 'uniform_' of 'torch._C._TensorBase' objects}
#     37883    0.260    0.000  519.803    0.014 transforms.py:282(forward)
#     37884    0.257    0.000    0.257    0.000 {method 't' of 'torch._C._TensorBase' objects}
#       342    0.251    0.001    0.251    0.001 {built-in method ctc_loss}
#     37883    0.237    0.000   34.441    0.001 soundfile.py:170(read)
#     37883    0.231    0.000   42.003    0.001 speechcommands.py:17(load_speechcommands_item)
#    189415    0.231    0.000    0.231    0.000 soundfile.py:696(__setattr__)
#       343    0.230    0.001    0.230    0.001 {method 'log_softmax' of 'torch._C._TensorBase' objects}
#     37882    0.228    0.000    0.228    0.000 {method 'clamp' of 'torch._C._TensorBase' objects}
#    196621    0.216    0.000    0.216    0.000 {built-in method torch._C._get_tracing_state}
#     77955    0.214    0.000    3.984    0.000 posixpath.py:376(abspath)
#     37883    0.186    0.000    7.428    0.000 functional.py:33(_stft)
#     37883    0.182    0.000    0.340    0.000 soundfile.py:1438(_get_format_from_filename)
#         1    0.178    0.178 5087.639 5087.639 <ipython-input-13-711c285a935b>:22(<module>)
#     37883    0.173    0.000    0.515    0.000 _dtype.py:333(_name_get)
#     37882    0.168    0.000    4.623    0.000 transforms.py:165(forward)
#     37883    0.165    0.000    0.240    0.000 soundfile.py:1392(_check_mode)
#    189415    0.161    0.000    0.161    0.000 soundfile.py:667(<lambda>)
#     37883    0.158    0.000  512.900    0.014 transforms.py:62(forward)
#     37883    0.147    0.000    0.662    0.000 soundfile.py:1411(_create_info_struct)
#    329283    0.146    0.000    0.146    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#    574356    0.139    0.000    0.139    0.000 {method 'startswith' of 'str' objects}
#    961806    0.139    0.000    0.140    0.000 {built-in method builtins.isinstance}
#     37908    0.137    0.000    0.137    0.000 {method 'item' of 'torch._C._TensorBase' objects}
#     37883    0.135    0.000    0.203    0.000 genericpath.py:69(commonprefix)
#    191664    0.132    0.000    0.132    0.000 {method 'split' of 'str' objects}
#     79590    0.131    0.000    0.132    0.000 {method 'format' of 'str' objects}
#    453788    0.129    0.000    0.189    0.000 posixpath.py:41(_get_sep)
#    171735    0.127    0.000    0.513    0.000 {built-in method builtins.getattr}
#     37883    0.124    0.000    0.383    0.000 soundfile.py:1336(_prepare_read)
# 722413/722129    0.121    0.000    0.147    0.000 {built-in method builtins.len}
#     75766    0.120    0.000    0.158    0.000 genericpath.py:121(_splitext)
#     37883    0.119    0.000    0.954    0.000 functional.py:2802(pad)
#       364    0.119    0.000    0.150    0.000 <frozen importlib._bootstrap_external>:914(get_data)
#     37883    0.117    0.000    0.179    0.000 posixpath.py:104(split)
#    764604    0.111    0.000    0.111    0.000 {built-in method posix.fspath}
#         1    0.106    0.106    0.106    0.106 {built-in method mkl._py_mkl_service.get_version}
#     75770    0.105    0.000    1.894    0.000 genericpath.py:27(isfile)
#     37883    0.105    0.000   16.741    0.000 soundfile.py:780(read)
#     37883    0.104    0.000    0.394    0.000 soundfile.py:1284(_create_empty_array)
#        20    0.101    0.005    0.101    0.005 {built-in method _imp.create_dynamic}
#    211672    0.099    0.000    1.048    0.000 utils.py:254(walk_files)
#     44178    0.095    0.000  572.863    0.013 <ipython-input-7-310bd55dac72>:11(__getitem__)
#    227298    0.093    0.000    0.143    0.000 soundfile.py:1253(_check_if_closed)
#     75766    0.087    0.000    0.270    0.000 posixpath.py:121(splitext)
#     37883    0.086    0.000  502.832    0.013 functional.py:680(norm)
#    554736    0.085    0.000    0.085    0.000 {method 'endswith' of 'str' objects}
#     37883    0.085    0.000   36.728    0.001 __init__.py:28(load)
#    220/76    0.084    0.000    0.575    0.008 os.py:278(walk)
#     37883    0.080    0.000    0.271    0.000 _dtype.py:319(_name_includes_bit_suffix)
#     37883    0.075    0.000  529.615    0.014 <ipython-input-6-ea6777c124d4>:5(_process)
#     79057    0.075    0.000    0.166    0.000 posixpath.py:64(isabs)
#     43798    0.070    0.000    0.070    0.000 tensor.py:462(<lambda>)
#    754286    0.070    0.000    0.070    0.000 {method 'append' of 'list' objects}
#     75766    0.069    0.000    0.117    0.000 numerictypes.py:293(issubclass_)
#     37883    0.069    0.000    0.190    0.000 numerictypes.py:365(issubdtype)
#    151532    0.069    0.000    0.069    0.000 soundfile.py:731(seekable)
#       690    0.066    0.000    0.066    0.000 {method 'fill_' of 'torch._C._TensorBase' objects}
#     37896    0.065    0.000    0.537    0.000 __init__.py:1497(__getattr__)
#    392884    0.065    0.000    0.065    0.000 {method 'values' of 'collections.OrderedDict' objects}
#    303064    0.064    0.000    0.064    0.000 soundfile.py:665(<lambda>)
#    155476    0.063    0.000    0.063    0.000 {built-in method builtins.issubclass}
#     37883    0.063    0.000    0.063    0.000 {method 'new' of 'CompiledFFI' objects}
#     40526    0.062    0.000    0.107    0.000 {built-in method builtins.any}
#       346    0.061    0.000  572.924    1.656 fetch.py:44(<listcomp>)
#     37883    0.060    0.000   42.062    0.001 speechcommands.py:70(__getitem__)
#       349    0.058    0.000    0.083    0.000 sampler.py:198(__iter__)
#    189430    0.058    0.000    0.058    0.000 {method 'rfind' of 'str' objects}
#     37886    0.058    0.000    0.066    0.000 <ipython-input-4-81394220ed8b>:52(padding)
#    265181    0.056    0.000    0.056    0.000 soundfile.py:1353(_error_check)
#     37886    0.056    0.000    0.221    0.000 <ipython-input-4-81394220ed8b>:58(apply_with_padding)
#     37883    0.055    0.000    0.185    0.000 soundfile.py:1262(_check_frames)
#     37886    0.051    0.000    0.051    0.000 <ipython-input-4-81394220ed8b>:56(<listcomp>)
#         2    0.050    0.025    1.136    0.568 speechcommands.py:36(__init__)
#        36    0.050    0.001    0.050    0.001 {built-in method zeros_like}
#     37883    0.049    0.000    0.269    0.000 <ipython-input-4-81394220ed8b>:73(<lambda>)
#     37886    0.048    0.000    0.099    0.000 <ipython-input-4-81394220ed8b>:55(map_with_dict)
#      3705    0.047    0.000    0.047    0.000 socket.py:342(send)
#     38478    0.046    0.000    0.046    0.000 {built-in method builtins.min}
#    227298    0.042    0.000    0.042    0.000 soundfile.py:1431(<genexpr>)
#     37883    0.041    0.000    0.058    0.000 soundfile.py:1137(flush)
#     75766    0.040    0.000    0.040    0.000 {method 'issuperset' of 'set' objects}
#     11472    0.040    0.000    0.040    0.000 {built-in method posix.lstat}
#    196479    0.039    0.000    0.039    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#     82312    0.038    0.000    0.038    0.000 {method 'join' of 'str' objects}
#    211670    0.038    0.000    0.038    0.000 speechcommands.py:67(<lambda>)
#     37883    0.038    0.000    0.038    0.000 {method 'indices' of 'slice' objects}
#     75766    0.037    0.000    0.236    0.000 soundfile.py:776(tell)
#     37887    0.037    0.000    0.037    0.000 {method 'difference' of 'set' objects}
#       364    0.036    0.000    0.036    0.000 {built-in method marshal.loads}
#     37883    0.034    0.000    0.043    0.000 _backend.py:34(_get_audio_backend_module)
#     37883    0.033    0.000    0.033    0.000 {method 'cast' of 'CompiledFFI' objects}
#     37883    0.033    0.000    0.033    0.000 __init__.py:1394(__contains__)
#       364    0.031    0.000    0.031    0.000 {method 'read' of '_io.FileIO' objects}
#     75766    0.031    0.000    0.031    0.000 soundfile.py:642(<lambda>)
#      3087    0.028    0.000 2126.713    0.689 conv.py:195(forward)
#       343    0.027    0.000 2129.991    6.210 container.py:98(forward)
#     37883    0.027    0.000    0.027    0.000 posixpath.py:475(<listcomp>)
#     37883    0.027    0.000    0.586    0.000 soundfile.py:693(__exit__)
#     38463    0.025    0.000    0.025    0.000 {method 'encode' of 'str' objects}
#     37883    0.024    0.000    0.024    0.000 posixpath.py:476(<listcomp>)
#       342    0.023    0.000    0.093    0.000 <ipython-input-13-711c285a935b>:64(<listcomp>)
#     37899    0.023    0.000    0.023    0.000 _dtype.py:36(_kind_name)
#     37883    0.023    0.000    0.023    0.000 soundfile.py:636(<lambda>)
#       437    0.021    0.000    0.021    0.000 {built-in method builtins.compile}
#     38226    0.021    0.000    0.021    0.000 {method 'intersection' of 'set' objects}
#     75766    0.020    0.000    0.020    0.000 soundfile.py:644(<lambda>)
#     44621    0.019    0.000    0.019    0.000 {method 'rstrip' of 'str' objects}
#     39112    0.019    0.000    0.019    0.000 {built-in method builtins.max}
#     37884    0.019    0.000    0.019    0.000 {built-in method sys.getfilesystemencoding}
#     75767    0.018    0.000    0.018    0.000 {built-in method _stat.S_ISREG}
#     37883    0.018    0.000    0.038    0.000 soundfile.py:687(__del__)
#     75766    0.018    0.000    0.018    0.000 soundfile.py:638(<lambda>)
#     37883    0.017    0.000    0.017    0.000 soundfile.py:1293(_check_dtype)
# 56168/56163    0.017    0.000    0.017    0.000 {built-in method builtins.hasattr}
#     77326    0.016    0.000    0.016    0.000 {method 'upper' of 'str' objects}
#     38275    0.016    0.000    0.016    0.000 {method 'numel' of 'torch._C._TensorBase' objects}
#      7579    0.016    0.000    0.047    0.000 tokenize.py:487(_tokenize)
#     44502    0.015    0.000    0.026    0.000 tensor.py:443(__len__)
#     37883    0.015    0.000    0.015    0.000 soundfile.py:640(<lambda>)
#    211754    0.014    0.000    0.014    0.000 {method 'is_dir' of 'posix.DirEntry' objects}
#     37883    0.014    0.000    0.014    0.000 {method 'sizeof' of 'CompiledFFI' objects}
#        22    0.013    0.001    0.013    0.001 {built-in method io.open}
#        22    0.012    0.001    0.013    0.001 {method 'readlines' of '_io._IOBase' objects}
#       345    0.012    0.000    0.012    0.000 <ipython-input-10-84abe26017ab>:21(<listcomp>)
#       690    0.012    0.000    0.030    0.000 rnn.py:329(<listcomp>)
#       342    0.012    0.000    2.521    0.007 optimizer.py:159(zero_grad)
#      1088    0.011    0.000    0.086    0.000 posixpath.py:400(_joinrealpath)
#   807/805    0.010    0.000    0.022    0.000 {built-in method builtins.__build_class__}
#     37961    0.010    0.000    0.010    0.000 {method 'values' of 'dict' objects}
#       346    0.010    0.000    0.026    0.000 std.py:310(format_meter)
#      8334    0.009    0.000    0.009    0.000 {built-in method __new__ of type object at 0x109bc1568}
#      3551    0.009    0.000    0.068    0.000 iostream.py:197(schedule)
#        15    0.009    0.001    0.009    0.001 {built-in method time.sleep}
#         7    0.009    0.001    0.009    0.001 {method 'tolist' of 'torch._C._TensorBase' objects}
#     37883    0.009    0.000    0.009    0.000 _backend.py:27(get_audio_backend)
#      6903    0.009    0.000    0.009    0.000 {method 'match' of 're.Pattern' objects}
#        10    0.008    0.001    0.191    0.019 inspect.py:714(getmodule)
#      2744    0.008    0.000    3.166    0.001 activation.py:93(forward)
#      6228    0.008    0.000    0.010    0.000 tensor.py:464(__hash__)
#         4    0.008    0.002    0.008    0.002 {built-in method randperm}
#       900    0.007    0.000    0.007    0.000 threading.py:216(__init__)
#       349    0.007    0.000  574.402    1.646 std.py:1077(__iter__)
#     11472    0.007    0.000    0.048    0.000 posixpath.py:168(islink)
#       345    0.006    0.000    0.040    0.000 <ipython-input-10-84abe26017ab>:22(<listcomp>)
#     37883    0.006    0.000    0.006    0.000 soundfile.py:690(__enter__)
#      4449    0.006    0.000    0.012    0.000 threading.py:1092(is_alive)
#       898    0.006    0.000    0.480    0.001 iostream.py:336(flush)
#         1    0.006    0.006    0.140    0.140 <ipython-input-13-711c285a935b>:4(<module>)
#       342    0.006    0.000    0.006    0.000 {built-in method full}
#       345    0.006    0.000    0.006    0.000 <ipython-input-10-84abe26017ab>:8(<listcomp>)
#       897    0.005    0.000    0.434    0.000 threading.py:264(wait)
#       856    0.005    0.000    0.055    0.000 iostream.py:384(write)
#      6249    0.005    0.000    0.018    0.000 re.py:271(_compile)
#       342    0.005    0.000    0.005    0.000 {built-in method ones_like}
#       488    0.004    0.000    0.311    0.001 std.py:1400(moveto)
#       497    0.004    0.000    0.055    0.000 <frozen importlib._bootstrap_external>:1356(find_spec)
#      2744    0.004    0.000    3.158    0.001 functional.py:904(relu)
#        47    0.004    0.000    0.004    0.000 {built-in method posix.listdir}
#   124/123    0.004    0.000    0.004    0.000 {built-in method builtins.dir}
#         1    0.004    0.004    0.004    0.004 {method 'dlopen' of 'CompiledFFI' objects}
#       899    0.004    0.000    0.440    0.000 threading.py:534(wait)
#        45    0.004    0.000    0.042    0.001 inputtransformer2.py:465(make_tokens_by_line)
#       345    0.004    0.000    0.811    0.002 <ipython-input-10-84abe26017ab>:6(collate_fn)
#       900    0.004    0.000    0.012    0.000 threading.py:499(__init__)
#       364    0.004    0.000    0.210    0.001 <frozen importlib._bootstrap_external>:793(get_code)
#      6138    0.004    0.000    0.004    0.000 {method 'detach_' of 'torch._C._TensorBase' objects}
#       342    0.004    0.000 2324.978    6.798 __init__.py:44(backward)
#       690    0.003    0.000    0.003    0.000 {method 'new' of 'torch._C._TensorBase' objects}
#      1004    0.003    0.000    0.004    0.000 PyColorize.py:284(_inner_call_)
#   1128/40    0.003    0.000    0.194    0.005 inspect.py:680(getsourcefile)
#       346    0.003    0.000    0.004    0.000 std.py:1405(format_dict)
#       343    0.003    0.000 2130.227    6.211 <ipython-input-12-f381d73c012c>:56(forward)
#       345    0.003    0.000    0.003    0.000 <ipython-input-10-84abe26017ab>:9(<listcomp>)
#       354    0.003    0.000    0.003    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       342    0.003    0.000 2324.981    6.798 tensor.py:167(backward)
#       692    0.003    0.000    0.004    0.000 utils.py:254(_is_ascii)
#      4449    0.003    0.000    0.005    0.000 threading.py:1050(_wait_for_tstate_lock)
#     12566    0.003    0.000    0.004    0.000 inspect.py:63(ismodule)
#       342    0.003    0.000    0.008    0.000 __init__.py:20(_make_grads)
#        86    0.003    0.000    0.010    0.000 traitlets.py:224(getmembers)
#         1    0.003    0.003    0.028    0.028 {built-in method torch._C._initExtension}
#       395    0.003    0.000    0.064    0.000 <frozen importlib._bootstrap>:882(_find_spec)
#        74    0.003    0.000    0.003    0.000 {built-in method posix.scandir}
#       346    0.003    0.000    0.562    0.002 std.py:1420(display)
#       349    0.002    0.000    0.004    0.000 tensor.py:448(__iter__)
#     11400    0.002    0.000    0.002    0.000 {method 'partition' of 'str' objects}
#      6271    0.002    0.000    0.002    0.000 {built-in method builtins.id}
#       728    0.002    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:271(cache_from_source)
#       346    0.002    0.000    0.572    0.002 std.py:1292(refresh)
#        85    0.002    0.000    0.002    0.000 {built-in method posix.urandom}
#      1148    0.002    0.000    0.002    0.000 <frozen importlib._bootstrap>:78(acquire)
#    753/61    0.002    0.000 5089.750   83.439 {built-in method builtins.exec}
#      6193    0.002    0.000    0.013    0.000 tokenize.py:147(_compile)
#      1148    0.002    0.000    0.003    0.000 <frozen importlib._bootstrap>:157(_get_module_lock)
#      3551    0.002    0.000    0.002    0.000 iostream.py:93(_event_pipe)
#       346    0.002    0.000  573.782    1.658 dataloader.py:383(_next_data)
#      6198    0.002    0.000    0.003    0.000 types.py:164(__get__)
#     17885    0.002    0.000    0.002    0.000 {method 'get' of 'dict' objects}
#        50    0.002    0.000    0.002    0.000 poll.py:77(poll)
#  1761/958    0.002    0.000    0.167    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#     396/4    0.002    0.000    0.623    0.156 <frozen importlib._bootstrap>:978(_find_and_load)
#       332    0.002    0.000    0.003    0.000 encoder.py:204(iterencode)
#      2825    0.002    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:56(_path_join)
#       856    0.002    0.000    0.010    0.000 iostream.py:322(_schedule_flush)
#       688    0.002    0.000    0.005    0.000 std.py:227(format_interval)
#       346    0.002    0.000    0.031    0.000 std.py:1067(__repr__)
#      1098    0.002    0.000    0.078    0.000 inspect.py:702(getabsfile)
#      2825    0.002    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:58(<listcomp>)
# 4893/4557    0.002    0.000    0.010    0.000 traitlets.py:545(__get__)
#      2584    0.002    0.000    0.002    0.000 {built-in method _thread.allocate_lock}
#     94/28    0.002    0.000    0.004    0.000 sre_parse.py:469(_parse)
#      1148    0.002    0.000    0.002    0.000 <frozen importlib._bootstrap>:103(release)
#       354    0.002    0.000    0.005    0.000 std.py:87(acquire)
# 3321/3191    0.002    0.000    0.008    0.000 traitlets.py:526(get)
#       271    0.002    0.000    0.011    0.000 traitlets.py:1142(notify_change)
#      6240    0.002    0.000    0.019    0.000 re.py:232(compile)
#     385/4    0.002    0.000    0.621    0.155 <frozen importlib._bootstrap>:663(_load_unlocked)
#     20/16    0.002    0.000    0.006    0.000 {built-in method _imp.exec_dynamic}
#      1896    0.002    0.000    0.002    0.000 inputtransformer2.py:103(_find_assign_op)
#       384    0.002    0.000    0.008    0.000 <frozen importlib._bootstrap>:504(_init_module_attrs)
#       346    0.002    0.000    0.216    0.001 std.py:297(fp_write)
#     396/4    0.002    0.000    0.623    0.156 <frozen importlib._bootstrap>:948(_find_and_load_unlocked)
#       856    0.001    0.000    0.002    0.000 iostream.py:309(_is_master_process)
#       346    0.001    0.000    0.002    0.000 std.py:154(__format__)
#       346    0.001    0.000  573.784    1.658 dataloader.py:344(__next__)
#        95    0.001    0.000    0.012    0.000 PyColorize.py:207(format2)
#      1088    0.001    0.000    0.097    0.000 posixpath.py:391(realpath)
#       354    0.001    0.000    0.001    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#       354    0.001    0.000    0.003    0.000 std.py:91(release)
#       346    0.001    0.000  573.736    1.658 fetch.py:42(fetch)
#       384    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:574(spec_from_file_location)
#       612    0.001    0.000    0.001    0.000 _inspect.py:67(getargs)
#       346    0.001    0.000    0.217    0.001 std.py:303(print_status)
#     364/4    0.001    0.000    0.621    0.155 <frozen importlib._bootstrap_external>:722(exec_module)
#       395    0.001    0.000    0.059    0.000 <frozen importlib._bootstrap_external>:1240(_get_spec)
#      6198    0.001    0.000    0.001    0.000 enum.py:628(value)
#       364    0.001    0.000    0.038    0.000 <frozen importlib._bootstrap_external>:523(_compile_bytecode)
#     11472    0.001    0.000    0.001    0.000 {built-in method _stat.S_ISLNK}
#       342    0.001    0.000    0.253    0.001 loss.py:1293(forward)
#       389    0.001    0.000    0.002    0.000 functools.py:37(update_wrapper)
#        55    0.001    0.000    0.002    0.000 traitlets.py:1371(<listcomp>)
#      2969    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#       364    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:438(_classify_pyc)
#       897    0.001    0.000    0.002    0.000 threading.py:252(_acquire_restore)
#    242/23    0.001    0.000    0.003    0.000 sre_compile.py:71(_compile)
#      7551    0.001    0.000    0.001    0.000 {built-in method builtins.ord}
#      4454    0.001    0.000    0.001    0.000 threading.py:507(is_set)
#       683    0.001    0.000    0.002    0.000 module.py:578(__setattr__)
#         4    0.001    0.000    0.001    0.000 {built-in method empty}
#        83    0.001    0.000    0.019    0.000 session.py:657(send)
#       286    0.001    0.000    0.004    0.000 overrides.py:72(verify_matching_signatures)
#      3447    0.001    0.000    0.001    0.000 {method 'rpartition' of 'str' objects}
#       192    0.001    0.000    0.001    0.000 attrsettr.py:50(_get_attr_opt)
#      4376    0.001    0.000    0.001    0.000 inspect.py:690(<genexpr>)
#        19    0.001    0.000    0.025    0.001 ultratb.py:899(format_record)
#       316    0.001    0.000    0.020    0.000 overrides.py:166(decorator)
#      4658    0.001    0.000    0.001    0.000 {method 'append' of 'collections.deque' objects}
#       384    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap>:318(__exit__)
#         4    0.001    0.000    0.001    0.000 {method 'reshape' of 'torch._C._TensorBase' objects}
#       958    0.001    0.000    0.001    0.000 threading.py:243(__exit__)
#        11    0.001    0.000    0.002    0.000 __init__.py:316(namedtuple)
#        47    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:1190(_path_hooks)
#       342    0.001    0.000    0.252    0.001 functional.py:1737(ctc_loss)
#    155/31    0.001    0.000    0.005    0.000 configurable.py:106(_find_my_config)
#      3384    0.001    0.000    0.001    0.000 inspect.py:687(<genexpr>)
#         1    0.001    0.001    0.001    0.001 {built-in method torch._C._c10d_init}
#        31    0.001    0.000    0.005    0.000 traitlets.py:961(setup_instance)
#      1061    0.001    0.000    0.058    0.000 genericpath.py:16(exists)
#      1460    0.001    0.000    0.050    0.000 <frozen importlib._bootstrap_external>:74(_path_stat)
#       332    0.001    0.000    0.005    0.000 __init__.py:183(dumps)
#       181    0.001    0.000    0.001    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#       752    0.001    0.000    0.004    0.000 <frozen importlib._bootstrap>:194(_lock_unlock_module)
#       677    0.001    0.000    0.001    0.000 std.py:268(ema)
#       958    0.001    0.000    0.001    0.000 threading.py:240(__enter__)
#      1196    0.001    0.000    0.002    0.000 inspect.py:642(getfile)
#        36    0.001    0.000    0.001    0.000 init.py:202(_calculate_fan_in_and_fan_out)
#       458    0.001    0.000    0.002    0.000 traitlets.py:587(_validate)
#      1724    0.001    0.000    0.001    0.000 sre_parse.py:164(__getitem__)
#       384    0.001    0.000    0.110    0.000 <frozen importlib._bootstrap>:576(module_from_spec)
#       354    0.001    0.000    0.014    0.000 traitlets.py:558(set)
#      1004    0.001    0.000    0.005    0.000 PyColorize.py:328(__call__)
#      1098    0.001    0.000    0.001    0.000 posixpath.py:52(normcase)
#       519    0.001    0.000    0.001    0.000 traitlets.py:419(__init__)
#     77/28    0.001    0.000 5090.108  181.790 gen.py:184(wrapper)
#        15    0.001    0.000 5090.010  339.334 interactiveshell.py:2920(run_cell_async)
#       343    0.001    0.000    0.231    0.001 functional.py:1297(log_softmax)
#       488    0.001    0.000    0.001    0.000 utils.py:333(_term_move_up)
#      1085    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:416(parent)
#      6172    0.001    0.000    0.001    0.000 {method 'span' of 're.Match' objects}
#       202    0.001    0.000    0.001    0.000 traitlets.py:486(_dynamic_default_callable)
#         1    0.001    0.001    0.001    0.001 negative_binomial.py:8(NegativeBinomial)
#       728    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:62(_path_split)
#         4    0.001    0.000    0.001    0.000 {method 'random_' of 'torch._C._TensorBase' objects}
#      2305    0.001    0.000    0.001    0.000 {built-in method builtins.setattr}
#      1400    0.001    0.000    0.001    0.000 loader.py:218(__contains__)
#        26    0.001    0.000    0.206    0.008 __init__.py:1(<module>)
#       103    0.001    0.000    0.001    0.000 sre_compile.py:276(_optimize_charset)
#        18    0.001    0.000    0.265    0.015 conv.py:18(__init__)
#        45    0.001    0.000    0.001    0.000 inputtransformer2.py:366(find)
#        83    0.001    0.000    0.009    0.000 session.py:598(serialize)
#       346    0.001    0.000    0.001    0.000 std.py:145(__init__)
#       310    0.001    0.000    0.001    0.000 configurable.py:102(<listcomp>)
#       332    0.001    0.000    0.006    0.000 jsonapi.py:31(dumps)
#        31    0.001    0.000 5090.079  164.196 kernelbase.py:512(execute_request)
#      1368    0.001    0.000    0.001    0.000 loader.py:150(_is_section_key)
#         1    0.001    0.001    0.001    0.001 functional.py:399(create_fb_matrix)
#        15    0.001    0.000 5089.989  339.333 interactiveshell.py:3142(run_ast_nodes)
#       384    0.001    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:369(_get_cached)
#        32    0.001    0.000    0.028    0.001 linecache.py:82(updatecache)
#      1267    0.001    0.000    0.001    0.000 {method 'update' of 'dict' objects}
#       332    0.001    0.000    0.004    0.000 encoder.py:182(encode)
#      1722    0.001    0.000    0.001    0.000 {built-in method builtins.divmod}
#    132/17    0.001    0.000    0.001    0.000 jsonutil.py:109(json_clean)
#       599    0.001    0.000    0.030    0.000 <frozen importlib._bootstrap_external>:84(_path_is_mode_type)
#       346    0.001    0.000    0.044    0.000 dataloader.py:338(_next_index)
#      1092    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:51(_r_long)
#       384    0.001    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:1351(_get_spec)
#        37    0.001    0.000 5090.106  137.570 kernelbase.py:225(dispatch_shell)
#      5039    0.001    0.000    0.001    0.000 {method 'isidentifier' of 'str' objects}
#      1368    0.001    0.000    0.002    0.000 loader.py:231(_has_section)
#       392    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:58(__init__)
#       956    0.001    0.000    0.001    0.000 threading.py:255(_is_owned)
#       616    0.001    0.000    0.002    0.000 _inspect.py:98(getargspec)
#       519    0.001    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:1203(_path_importer_cache)
#       343    0.001    0.000    0.001    0.000 traitlets.py:651(tag)
#       381    0.001    0.000    0.001    0.000 traitlets.py:596(_cross_validate)
#       748    0.001    0.000    0.004    0.000 <frozen importlib._bootstrap>:403(cached)
#       392    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:176(cb)
#       525    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.588    0.588 __init__.py:11(<module>)
#       343    0.000    0.000    0.001    0.000 container.py:94(__iter__)
#       897    0.000    0.000    0.001    0.000 threading.py:249(_release_save)
#        20    0.000    0.000 5101.043  255.052 base_events.py:1686(_run_once)
#    282/68    0.000    0.000    0.001    0.000 sre_parse.py:174(getwidth)
#       105    0.000    0.000    0.002    0.000 session.py:583(sign)
#       120    0.000    0.000    0.000    0.000 {method 'replace' of 'datetime.datetime' objects}
#       271    0.000    0.000    0.011    0.000 traitlets.py:1133(_notify_trait)
#       364    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:471(_validate_timestamp_pyc)
#        22    0.000    0.000    0.000    0.000 __init__.py:454(_dummy_type)
#        45    0.000    0.000    0.046    0.001 inputtransformer2.py:573(do_token_transforms)
#       940    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#       364    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#      2736    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#      2736    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#       364    0.000    0.000    0.012    0.000 <frozen importlib._bootstrap_external>:951(path_stats)
#        19    0.000    0.000    0.013    0.001 ultratb.py:385(_format_traceback_lines)
#      1047    0.000    0.000    0.000    0.000 {built-in method time.time}
#     61/15    0.000    0.000 5090.113  339.341 gen.py:716(run)
#         1    0.000    0.000    0.000    0.000 {built-in method hann_window}
#    361/28    0.000    0.000    0.221    0.008 {built-in method builtins.__import__}
#        22    0.000    0.000    0.000    0.000 socket.py:449(recv_multipart)
#       291    0.000    0.000    0.000    0.000 contextlib.py:81(__init__)
#       273    0.000    0.000    0.003    0.000 function_base.py:460(add_newdoc)
#       842    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#        22    0.000    0.000    0.003    0.000 session.py:881(deserialize)
#       855    0.000    0.000    0.000    0.000 sre_parse.py:233(__next)
#       354    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#       346    0.000    0.000    0.000    0.000 utils.py:135(__init__)
#       958    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#        22    0.000    0.000    0.014    0.001 tokenize.py:443(open)
#        61    0.000    0.000 5089.985   83.442 interactiveshell.py:3293(run_code)
#        85    0.000    0.000    0.001    0.000 traitlets.py:742(setup_class)
#        45    0.000    0.000    0.001    0.000 inputtransformer2.py:243(find)
#      1196    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:859(__exit__)
#       364    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:35(_new_module)
#       364    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:401(_check_name_wrapper)
#        85    0.000    0.000    0.003    0.000 traitlets.py:722(__new__)
#       418    0.000    0.000    0.001    0.000 {built-in method _abc._abc_instancecheck}
#      2403    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#       160    0.000    0.000    0.002    0.000 traitlets.py:516(instance_init)
#       130    0.000    0.000    0.002    0.000 zmqstream.py:534(_update_handler)
#       158    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#      1093    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#       332    0.000    0.000    0.000    0.000 encoder.py:104(__init__)
#        31    0.000    0.000    0.003    0.000 traitlets.py:1407(traits)
#      1196    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:855(__enter__)
#        89    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#       396    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:369(__init__)
#       583    0.000    0.000    0.000    0.000 {built-in method torch._C._add_docstr}
#         1    0.000    0.000    0.000    0.000 {method 'dot' of 'numpy.ndarray' objects}
#        31    0.000    0.000    0.001    0.000 traitlets.py:1421(<listcomp>)
#       396    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:151(__exit__)
#        83    0.000    0.000    0.003    0.000 session.py:121(new_id)
#         1    0.000    0.000    0.000    0.000 <ipython-input-7-310bd55dac72>:6(__init__)
#       396    0.000    0.000    0.004    0.000 <frozen importlib._bootstrap>:147(__enter__)
#        47    0.000    0.000    0.006    0.000 zmqstream.py:313(flush)
#       395    0.000    0.000    0.059    0.000 <frozen importlib._bootstrap_external>:1272(find_spec)
#        44    0.000    0.000    0.009    0.000 kernelbase.py:460(_publish_status)
#       552    0.000    0.000    0.030    0.000 <frozen importlib._bootstrap_external>:93(_path_isfile)
#       332    0.000    0.000    0.006    0.000 session.py:102(<lambda>)
#        45    0.000    0.000    0.001    0.000 inputtransformer2.py:211(find)
#       286    0.000    0.000    0.000    0.000 queue.py:96(empty)
#       898    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#        45    0.000    0.000    0.047    0.001 inputtransformer2.py:582(transform_cell)
#        83    0.000    0.000    0.005    0.000 session.py:564(msg)
#       497    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:36(_relax_case)
#       912    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#        88    0.000    0.000    0.000    0.000 decoder.py:343(raw_decode)
#       135    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#        55    0.000    0.000    0.010    0.000 traitlets.py:1354(class_traits)
#        15    0.000    0.000 5090.051  339.337 ipkernel.py:262(do_execute)
#     77/23    0.000    0.000    0.005    0.000 sre_parse.py:411(_parse_sub)
#        15    0.000    0.000    0.000    0.000 arrayprint.py:1482(_guarded_repr_or_str)
#         1    0.000    0.000    0.012    0.012 numeric.py:1(<module>)
#       342    0.000    0.000    0.000    0.000 _reduction.py:6(get_enum)
#      1536    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:321(<genexpr>)
#         3    0.000    0.000    0.000    0.000 {built-in method isfinite}
#        47    0.000    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:1404(_fill_cache)
#     491/4    0.000    0.000    0.608    0.152 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#       958    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        15    0.000    0.000    0.002    0.000 history.py:691(store_inputs)
#      1464    0.000    0.000    0.000    0.000 ipstruct.py:125(__getattr__)
#       315    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HASH' objects}
#      1460    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        45    0.000    0.000    0.048    0.001 interactiveshell.py:3081(transform_cell)
#       159    0.000    0.000    0.000    0.000 events.py:39(__init__)
#       105    0.000    0.000    0.001    0.000 hmac.py:104(copy)
#       384    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:311(__enter__)
#         4    0.000    0.000    0.002    0.001 _tensor_str.py:72(__init__)
#        24    0.000    0.000    0.000    0.000 {method 'readline' of '_io.BufferedReader' objects}
#        20    0.000    0.000    0.021    0.001 ultratb.py:163(findsource)
#       354    0.000    0.000    0.014    0.000 traitlets.py:576(__set__)
#       365    0.000    0.000    0.000    0.000 functools.py:67(wraps)
#       181    0.000    0.000    0.001    0.000 jsonutil.py:87(date_default)
#       291    0.000    0.000    0.001    0.000 contextlib.py:116(__exit__)
#       135    0.000    0.000    0.001    0.000 codecs.py:319(decode)
#       291    0.000    0.000    0.001    0.000 contextlib.py:107(__enter__)
#       346    0.000    0.000    0.000    0.000 utils.py:139(__format__)
#         1    0.000    0.000    0.000    0.000 {built-in method topk}
#       972    0.000    0.000    0.000    0.000 inspect.py:72(isclass)
#       101    0.000    0.000    0.000    0.000 gen.py:814(convert_yielded)
#       684    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#        83    0.000    0.000    0.004    0.000 session.py:561(msg_header)
#       352    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#      2251    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#       101    0.000    0.000    0.001    0.000 gen.py:770(handle_yield)
#       605    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         2    0.000    0.000    0.016    0.008 traceback.py:318(extract)
#        22    0.000    0.000    0.002    0.000 socket.py:402(send_multipart)
#     90/37    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#       158    0.000    0.000    0.001    0.000 base_events.py:706(_call_soon)
#         1    0.000    0.000    0.002    0.002 core.py:21(<module>)
#        18    0.000    0.000    0.264    0.015 conv.py:48(reset_parameters)
#       573    0.000    0.000    0.000    0.000 bunch.py:11(__getattr__)
#       384    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:307(__init__)
#        22    0.000    0.000    0.001    0.000 adapter.py:368(adapt)
#        91    0.000    0.000    0.001    0.000 asyncio.py:175(add_callback)
#        61    0.000    0.000    0.002    0.000 codeop.py:135(__call__)
#       396    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#       120    0.000    0.000    0.001    0.000 session.py:169(utcnow)
#        78    0.000    0.000    0.000    0.000 gen.py:141(_create_future)
#       124    0.000    0.000    0.000    0.000 traitlets.py:1067(hold_trait_notifications)
#     54/33    0.000    0.000 5090.010  154.243 gen.py:700(__init__)
#        45    0.000    0.000    0.001    0.000 module.py:69(__init__)
#      1004    0.000    0.000    0.000    0.000 {method 'read' of '_io.StringIO' objects}
#         2    0.000    0.000    0.003    0.002 function_base.py:1(<module>)
#        55    0.000    0.000    0.011    0.000 widget.py:269(reg)
#       192    0.000    0.000    0.001    0.000 attrsettr.py:38(__getattr__)
#       395    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#       124    0.000    0.000    0.028    0.000 linecache.py:37(getlines)
#        45    0.000    0.000    0.046    0.001 inputtransformer2.py:541(do_one_token_transform)
#       364    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:884(__init__)
#       291    0.000    0.000    0.001    0.000 contextlib.py:237(helper)
#    154/44    0.000    0.000    0.000    0.000 jsonutil.py:62(extract_dates)
#         1    0.000    0.000    0.009    0.009 multiarray.py:7(<module>)
#       106    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#       101    0.000    0.000    0.000    0.000 weakref.py:395(__getitem__)
#       108    0.000    0.000    0.001    0.000 zmqstream.py:511(_rebuild_io_state)
#       616    0.000    0.000    0.000    0.000 _inspect.py:15(ismethod)
#        45    0.000    0.000    0.000    0.000 inputtransformer2.py:426(find)
#         1    0.000    0.000    0.048    0.048 __init__.py:7(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._autograd_init}
#       310    0.000    0.000    0.001    0.000 configurable.py:99(section_names)
#        47    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1319(__init__)
#         1    0.000    0.000    0.232    0.232 __init__.py:106(<module>)
#       395    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:792(find_spec)
#        23    0.000    0.000    0.008    0.000 sre_compile.py:759(compile)
#       670    0.000    0.000    0.000    0.000 sre_parse.py:254(get)
#        59    0.000    0.000    0.000    0.000 threading.py:335(notify)
#         1    0.000    0.000    0.000    0.000 {built-in method tensor}
#        47    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1433(<setcomp>)
#       105    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#       461    0.000    0.000    0.000    0.000 traitlets.py:383(class_init)
#        62    0.000    0.000    0.002    0.000 zmqstream.py:446(_handle_events)
#        76    0.000    0.000    0.000    0.000 enum.py:526(__new__)
#       120    0.000    0.000    0.000    0.000 {built-in method utcnow}
#        18    0.000    0.000    0.263    0.015 init.py:283(kaiming_uniform_)
#         1    0.000    0.000    0.002    0.002 numerictypes.py:81(<module>)
#        88    0.000    0.000    0.001    0.000 decoder.py:332(decode)
#       273    0.000    0.000    0.000    0.000 function_base.py:428(_needs_add_docstring)
#         1    0.000    0.000    0.001    0.001 getlimits.py:96(_register_known_types)
#       198    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        28    0.000    0.000    0.000    0.000 traitlets.py:2150(__init__)
#        59    0.000    0.000    0.000    0.000 kernelbase.py:780(_topic)
#       616    0.000    0.000    0.000    0.000 _inspect.py:28(isfunction)
#        10    0.000    0.000    0.000    0.000 function.py:90(__init__)
#       354    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#        85    0.000    0.000    0.001    0.000 traitlets.py:737(__init__)
#        90    0.000    0.000    0.000    0.000 utils.py:6(parse)
#        15    0.000    0.000 5090.010  339.334 {method 'send' of 'coroutine' objects}
#       249    0.000    0.000    0.000    0.000 session.py:132(<genexpr>)
#         4    0.000    0.000    0.002    0.001 _tensor_str.py:247(_str)
#       566    0.000    0.000    0.000    0.000 sre_parse.py:160(__len__)
#        20    0.000    0.000    0.208    0.010 inspect.py:1444(getframeinfo)
#         1    0.000    0.000    0.000    0.000 tempfile.py:142(rng)
#       158    0.000    0.000    0.001    0.000 base_events.py:677(call_soon)
#       166    0.000    0.000    0.000    0.000 {built-in method binascii.b2a_hex}
#       317    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#        31    0.000    0.000    0.010    0.000 configurable.py:38(__init__)
#        52    0.000    0.000    0.000    0.000 core.py:900(__init__)
#         1    0.000    0.000    0.034    0.034 __init__.py:13(<module>)
#        22    0.000    0.000    0.001    0.000 tokenize.py:350(detect_encoding)
#        21    0.000    0.000    0.000    0.000 traitlets.py:1966(__init__)
#       105    0.000    0.000    0.000    0.000 traitlets.py:2535(validate_elements)
#       105    0.000    0.000    0.001    0.000 traitlets.py:2528(validate)
#        22    0.000    0.000    0.001    0.000 zmqshell.py:573(set_parent)
#         1    0.000    0.000    0.023    0.023 __init__.py:9(<module>)
#         1    0.000    0.000    0.001    0.001 _torch_docs.py:1(<module>)
#       465    0.000    0.000    0.000    0.000 sre_parse.py:249(match)
#       165    0.000    0.000    0.016    0.000 traceback.py:282(line)
#        62    0.000    0.000    0.000    0.000 traitlets.py:1627(__init__)
#       286    0.000    0.000    0.001    0.000 zmqstream.py:425(sending)
#         1    0.000    0.000    0.004    0.004 defchararray.py:17(<module>)
#        23    0.000    0.000    0.000    0.000 {built-in method _abc._abc_init}
#        88    0.000    0.000    0.001    0.000 jsonapi.py:47(loads)
#        31    0.000    0.000    0.008    0.000 configurable.py:170(_config_changed)
#       162    0.000    0.000 5090.113   31.420 events.py:86(_run)
#      1400    0.000    0.000    0.000    0.000 {function Config.__contains__ at 0x10a3cd4d0}
#        22    0.000    0.000    0.001    0.000 zmqstream.py:267(send_multipart)
#         6    0.000    0.000    0.003    0.001 utils.py:1(<module>)
#       103    0.000    0.000    0.000    0.000 sre_compile.py:249(_compile_charset)
#        58    0.000    0.000    0.000    0.000 os.py:674(__getitem__)
#         1    0.000    0.000    0.003    0.003 _add_newdocs.py:10(<module>)
#       120    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#       612    0.000    0.000    0.000    0.000 _inspect.py:43(iscode)
#       418    0.000    0.000    0.001    0.000 abc.py:137(__instancecheck__)
#       101    0.000    0.000    0.001    0.000 functools.py:835(wrapper)
#         1    0.000    0.000    0.000    0.000 {function Random.seed at 0x10a3bca70}
#        23    0.000    0.000    0.000    0.000 sre_compile.py:536(_compile_info)
#        85    0.000    0.000    0.001    0.000 traitlets.py:757(setup_class)
#       155    0.000    0.000    0.000    0.000 loader.py:161(__init__)
#        83    0.000    0.000    0.000    0.000 session.py:739(<listcomp>)
#        76    0.000    0.000    0.000    0.000 enum.py:284(__call__)
#       215    0.000    0.000    0.000    0.000 traitlets.py:1673(validate)
#         6    0.000    0.000    0.001    0.000 getlimits.py:37(__init__)
#         1    0.000    0.000    0.000    0.000 functional.py:441(create_dct)
# ...
#         1    0.000    0.000    0.000    0.000 stride_tricks.py:16(DummyArray)
#         1    0.000    0.000    0.000    0.000 polynomial.py:30(RankWarning)
#         1    0.000    0.000    0.000    0.000 _iotools.py:470(ConverterError)
#         1    0.000    0.000    0.000    0.000 _iotools.py:478(ConverterLockError)
#         1    0.000    0.000    0.000    0.000 _iotools.py:486(ConversionWarning)
#         1    0.000    0.000    0.000    0.000 polyutils.py:62(RankWarning)
#         1    0.000    0.000    0.000    0.000 polyutils.py:66(PolyError)
#         1    0.000    0.000    0.000    0.000 polyutils.py:70(PolyDomainError)
#         1    0.000    0.000    0.000    0.000 polyutils.py:83(PolyBase)
#         1    0.000    0.000    0.000    0.000 core.py:91(MaskedArrayFutureWarning)
#         1    0.000    0.000    0.000    0.000 core.py:162(MAError)
#         1    0.000    0.000    0.000    0.000 core.py:170(MaskError)
#         1    0.000    0.000    0.000    0.000 core.py:204(<listcomp>)
#         1    0.000    0.000    0.000    0.000 core.py:803(_DomainCheckInterval)
#         1    0.000    0.000    0.000    0.000 core.py:828(_DomainTan)
#         1    0.000    0.000    0.000    0.000 core.py:867(_DomainGreater)
#         2    0.000    0.000    0.000    0.000 core.py:889(__init__)
#         1    0.000    0.000    0.000    0.000 core.py:899(_MaskedUFunc)
#         1    0.000    0.000    0.000    0.000 core.py:1131(_DomainedBinaryOperation)
#         2    0.000    0.000    0.000    0.000 core.py:3379(shape)
#         1    0.000    0.000    0.000    0.000 core.py:6376(__array_finalize__)
#         1    0.000    0.000    0.000    0.000 extras.py:217(_fromnxfunction)
#         1    0.000    0.000    0.000    0.000 extras.py:290(_fromnxfunction_seq)
#         1    0.000    0.000    0.000    0.000 extras.py:303(_fromnxfunction_args)
#         1    0.000    0.000    0.000    0.000 serialization.py:33(SourceChangeWarning)
#         1    0.000    0.000    0.000    0.000 serialization.py:180(_opener)
#         1    0.000    0.000    0.000    0.000 serialization.py:205(_open_buffer_writer)
#         1    0.000    0.000    0.000    0.000 serialization.py:222(_open_zipfile_reader)
#         1    0.000    0.000    0.000    0.000 serialization.py:227(_open_zipfile_writer_file)
#         1    0.000    0.000    0.000    0.000 serialization.py:235(_open_zipfile_writer_buffer)
#         1    0.000    0.000    0.000    0.000 tarfile.py:273(TarError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:276(ExtractError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:279(ReadError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:282(CompressionError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:291(EmptyHeaderError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:297(EOFHeaderError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:300(InvalidHeaderError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:303(SubsequentHeaderError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:714(ExFileObject)
#         1    0.000    0.000    0.000    0.000 _tensor_str.py:6(__PrinterOptions)
#         1    0.000    0.000    0.000    0.000 _tensor_str.py:132(width)
#         1    0.000    0.000    0.000    0.000 _tensor_str.py:71(_Formatter)
#         1    0.000    0.000    0.000    0.000 __init__.py:154(DeferredCudaCallError)
#         1    0.000    0.000    0.000    0.000 __init__.py:228(CudaError)
#         1    0.000    0.000    0.000    0.000 __init__.py:265(device_of)
#         1    0.000    0.000    0.000    0.000 __init__.py:498(FloatStorage)
#         1    0.000    0.000    0.000    0.000 __init__.py:506(IntStorage)
#         1    0.000    0.000    0.000    0.000 __init__.py:510(ShortStorage)
#         1    0.000    0.000    0.000    0.000 __init__.py:514(CharStorage)
#         1    0.000    0.000    0.000    0.000 __init__.py:518(ByteStorage)
#         1    0.000    0.000    0.000    0.000 __init__.py:526(BoolStorage)
#         1    0.000    0.000    0.000    0.000 __init__.py:530(BFloat16Storage)
#         4    0.000    0.000    0.000    0.000 utils.py:5(_ntuple)
#         1    0.000    0.000    0.000    0.000 _VF.py:6(VFModule)
#         2    0.000    0.000    0.000    0.000 _jit_internal.py:545(is_dict)
#         1    0.000    0.000    0.000    0.000 _jit_internal.py:666(BroadcastingListCls)
#         1    0.000    0.000    0.000    0.000 conv.py:347(Conv3d)
#         1    0.000    0.000    0.000    0.000 conv.py:483(_ConvTransposeMixin)
#         1    0.000    0.000    0.000    0.000 conv.py:781(ConvTranspose3d)
#         1    0.000    0.000    0.000    0.000 activation.py:249(Sigmoid)
#         1    0.000    0.000    0.000    0.000 activation.py:274(Tanh)
#         1    0.000    0.000    0.000    0.000 activation.py:336(CELU)
#         1    0.000    0.000    0.000    0.000 activation.py:422(GLU)
#         1    0.000    0.000    0.000    0.000 activation.py:454(GELU)
#         1    0.000    0.000    0.000    0.000 activation.py:822(PReLU)
#         1    0.000    0.000    0.000    0.000 activation.py:885(Softsign)
#         1    0.000    0.000    0.000    0.000 activation.py:1024(Softmax2d)
#         1    0.000    0.000    0.000    0.000 loss.py:17(_WeightedLoss)
#         1    0.000    0.000    0.000    0.000 loss.py:207(NLLLoss2d)
#         1    0.000    0.000    0.000    0.000 loss.py:216(PoissonNLLLoss)
#         1    0.000    0.000    0.000    0.000 loss.py:287(KLDivLoss)
#         1    0.000    0.000    0.000    0.000 loss.py:604(HingeEmbeddingLoss)
#         1    0.000    0.000    0.000    0.000 loss.py:785(SoftMarginLoss)
#         1    0.000    0.000    0.000    0.000 loss.py:966(CosineEmbeddingLoss)
#         1    0.000    0.000    0.000    0.000 loss.py:1012(MarginRankingLoss)
#         1    0.000    0.000    0.000    0.000 loss.py:1058(MultiMarginLoss)
#         1    0.000    0.000    0.000    0.000 loss.py:1194(CTCLoss)
#         1    0.000    0.000    0.000    0.000 pooling.py:30(MaxPool1d)
#         1    0.000    0.000    0.000    0.000 pooling.py:79(MaxPool2d)
#         1    0.000    0.000    0.000    0.000 pooling.py:144(MaxPool3d)
#         1    0.000    0.000    0.000    0.000 pooling.py:213(_MaxUnpoolNd)
#         1    0.000    0.000    0.000    0.000 pooling.py:433(AvgPool1d)
#         1    0.000    0.000    0.000    0.000 pooling.py:696(FractionalMaxPool3d)
#         1    0.000    0.000    0.000    0.000 pooling.py:754(_LPPoolNd)
#         1    0.000    0.000    0.000    0.000 pooling.py:769(LPPool1d)
#         1    0.000    0.000    0.000    0.000 pooling.py:809(LPPool2d)
#         1    0.000    0.000    0.000    0.000 pooling.py:878(AdaptiveMaxPool1d)
#         1    0.000    0.000    0.000    0.000 pooling.py:901(AdaptiveMaxPool2d)
#         1    0.000    0.000    0.000    0.000 pooling.py:935(AdaptiveMaxPool3d)
#         1    0.000    0.000    0.000    0.000 pooling.py:1002(AdaptiveAvgPool2d)
#         1    0.000    0.000    0.000    0.000 pooling.py:1034(AdaptiveAvgPool3d)
#         1    0.000    0.000    0.000    0.000 batchnorm.py:77(_BatchNorm)
#         1    0.000    0.000    0.000    0.000 batchnorm.py:110(BatchNorm1d)
#         1    0.000    0.000    0.000    0.000 batchnorm.py:182(BatchNorm2d)
#         1    0.000    0.000    0.000    0.000 batchnorm.py:254(BatchNorm3d)
#         1    0.000    0.000    0.000    0.000 variable.py:5(VariableMeta)
#         1    0.000    0.000    0.000    0.000 function.py:62(_HookMixin)
#         1    0.000    0.000    0.000    0.000 function.py:80(FunctionMeta)
#         1    0.000    0.000    0.000    0.000 profiler.py:590(FunctionEventAvg)
#         1    0.000    0.000    0.000    0.000 profiler.py:637(StringTable)
#         1    0.000    0.000    0.000    0.000 instancenorm.py:52(InstanceNorm1d)
#         1    0.000    0.000    0.000    0.000 instancenorm.py:133(InstanceNorm2d)
#         1    0.000    0.000    0.000    0.000 dropout.py:141(AlphaDropout)
#         1    0.000    0.000    0.000    0.000 padding.py:23(ConstantPad1d)
#         1    0.000    0.000    0.000    0.000 padding.py:72(ConstantPad2d)
#         1    0.000    0.000    0.000    0.000 padding.py:121(ConstantPad3d)
#         1    0.000    0.000    0.000    0.000 padding.py:169(ReflectionPad1d)
#         1    0.000    0.000    0.000    0.000 padding.py:208(ReflectionPad2d)
#         1    0.000    0.000    0.000    0.000 padding.py:268(ReplicationPad1d)
#         1    0.000    0.000    0.000    0.000 padding.py:395(ZeroPad2d)
#         1    0.000    0.000    0.000    0.000 rnn.py:781(RNNCell)
#         1    0.000    0.000    0.000    0.000 spectral_norm.py:191(SpectralNormStateDictHook)
#         1    0.000    0.000    0.000    0.000 transformer.py:140(TransformerEncoder)
#         1    0.000    0.000    0.000    0.000 transformer.py:235(TransformerEncoderLayer)
#         1    0.000    0.000    0.000    0.000 transformer.py:295(TransformerDecoderLayer)
#         1    0.000    0.000    0.000    0.000 distributed_c10d.py:44(Backend)
#         1    0.000    0.000    0.000    0.000 distributed_c10d.py:86(reduce_op)
#         3    0.000    0.000    0.000    0.000 rendezvous.py:15(register_rendezvous_handler)
#         1    0.000    0.000    0.000    0.000 fused.py:5(ConvReLU2d)
#         1    0.000    0.000    0.000    0.000 fused.py:14(ConvReLU3d)
#         1    0.000    0.000    0.000    0.000 fused.py:23(LinearReLU)
#         1    0.000    0.000    0.000    0.000 __init__.py:517(TracingCheckError)
#         1    0.000    0.000    0.000    0.000 __init__.py:1455(<listcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1487(_CachedForward)
#         1    0.000    0.000    0.000    0.000 __init__.py:305(RNNDescriptor)
#         1    0.000    0.000    0.000    0.000 _recursive.py:219(ConcreteTypeStore)
#         1    0.000    0.000    0.000    0.000 _recursive.py:257(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _recursive.py:258(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _recursive.py:415(get_overload_name_mapping)
#         1    0.000    0.000    0.000    0.000 frontend.py:105(NotSupportedError)
#         1    0.000    0.000    0.000    0.000 frontend.py:109(UnsupportedNodeError)
#         1    0.000    0.000    0.000    0.000 frontend.py:176(SourceContext)
#         1    0.000    0.000    0.000    0.000 frontend.py:182(Builder)
#         1    0.000    0.000    0.000    0.000 lr_scheduler.py:428(CosineAnnealingLR)
#         1    0.000    0.000    0.000    0.000 lr_scheduler.py:886(CosineAnnealingWarmRestarts)
#         1    0.000    0.000    0.000    0.000 context.py:14(ProcessError)
#         1    0.000    0.000    0.000    0.000 context.py:17(BufferTooShort)
#         1    0.000    0.000    0.000    0.000 context.py:20(TimeoutError)
#         1    0.000    0.000    0.000    0.000 context.py:23(AuthenticationError)
#         1    0.000    0.000    0.000    0.000 context.py:219(Process)
#         1    0.000    0.000    0.000    0.000 context.py:272(ForkProcess)
#         1    0.000    0.000    0.000    0.000 context.py:286(ForkServerProcess)
#         1    0.000    0.000    0.000    0.000 context.py:293(ForkContext)
#         1    0.000    0.000    0.000    0.000 process.py:325(AuthenticationString)
#         1    0.000    0.000    0.000    0.000 util.py:345(ForkAwareThreadLock)
#         1    0.000    0.000    0.000    0.000 util.py:362(ForkAwareLocal)
#         1    0.000    0.000    0.000    0.000 resource_sharer.py:45(DupFd)
#         1    0.000    0.000    0.000    0.000 spawn.py:44(SpawnContext)
#         1    0.000    0.000    0.000    0.000 connection.py:754(ConnectionWrapper)
#         1    0.000    0.000    0.000    0.000 connection.py:776(XmlListener)
#         1    0.000    0.000    0.000    0.000 __init__.py:17(ExportTypes)
#         1    0.000    0.000    0.000    0.000 zipfile.py:38(BadZipFile)
#         1    0.000    0.000    0.000    0.000 zipfile.py:627(LZMADecompressor)
#         1    0.000    0.000    0.000    0.000 std.py:34(TqdmTypeError)
#         1    0.000    0.000    0.000    0.000 std.py:38(TqdmKeyError)
#         1    0.000    0.000    0.000    0.000 std.py:42(TqdmWarning)
#         1    0.000    0.000    0.000    0.000 std.py:55(TqdmExperimentalWarning)
#         1    0.000    0.000    0.000    0.000 utils.py:129(FormatReplace)
#         1    0.000    0.000    0.000    0.000 utils.py:207(CallbackIOWrapper)
#         1    0.000    0.000    0.000    0.000 _monitor.py:8(TqdmSynchronisationWarning)
#         1    0.000    0.000    0.000    0.000 widget.py:213(_show_traceback)
#         1    0.000    0.000    0.000    0.000 docutils.py:4(<module>)
#         1    0.000    0.000    0.000    0.000 constraints.py:52(Constraint)
#         1    0.000    0.000    0.000    0.000 constraints.py:70(_Dependent)
#         1    0.000    0.000    0.000    0.000 constraints.py:83(_DependentProperty)
#         1    0.000    0.000    0.000    0.000 constraints.py:109(_IntegerInterval)
#         1    0.000    0.000    0.000    0.000 constraints.py:126(_IntegerLessThan)
#         1    0.000    0.000    0.000    0.000 constraints.py:170(__init__)
#         1    0.000    0.000    0.000    0.000 constraints.py:218(__init__)
#         1    0.000    0.000    0.000    0.000 constraints.py:231(_HalfOpenInterval)
#         1    0.000    0.000    0.000    0.000 constraints.py:248(_Simplex)
#         1    0.000    0.000    0.000    0.000 constraints.py:257(_LowerTriangular)
#         1    0.000    0.000    0.000    0.000 constraints.py:278(_PositiveDefinite)
#         1    0.000    0.000    0.000    0.000 constraints.py:292(_RealVector)
#         1    0.000    0.000    0.000    0.000 constraints.py:301(_Cat)
#         1    0.000    0.000    0.000    0.000 __init__.py:13(cuFFTPlanCacheAttrContextProp)
#         1    0.000    0.000    0.000    0.000 sampler.py:130(WeightedRandomSampler)
#         1    0.000    0.000    0.000    0.000 sampler.py:166(BatchSampler)
#         1    0.000    0.000    0.000    0.000 dataset.py:35(IterableDataset)
#         1    0.000    0.000    0.000    0.000 dataset.py:244(Subset)
#         1    0.000    0.000    0.000    0.000 dataloader.py:374(_SingleProcessDataLoaderIter)
#         1    0.000    0.000    0.000    0.000 fetch.py:7(_BaseDatasetFetcher)
#         1    0.000    0.000    0.000    0.000 fetch.py:18(_IterableDatasetFetcher)
#         1    0.000    0.000    0.000    0.000 fetch.py:38(_MapDatasetFetcher)
#         1    0.000    0.000    0.000    0.000 _classes.py:3(_Classes)
#         1    0.000    0.000    0.000    0.000 utils.py:350(_End)
#         1    0.000    0.000    0.000    0.000 csv.py:70(unix_dialect)
#         1    0.000    0.000    0.000    0.000 _soundfile_backend.py:14(SignalInfo)
#         1    0.000    0.000    0.000    0.000 _soundfile_backend.py:22(EncodingInfo)
#         1    0.000    0.000    0.000    0.000 transforms.py:139(AmplitudeToDB)
#         1    0.000    0.000    0.000    0.000 transforms.py:178(MelScale)
#         1    0.000    0.000    0.000    0.000 transforms.py:463(ComplexNorm)
#         1    0.000    0.000    0.000    0.000 transforms.py:592(FrequencyMasking)
#         1    0.000    0.000    0.000    0.000 <ipython-input-4-81394220ed8b>:2(<module>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-10-84abe26017ab>:6(<module>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-4-81394220ed8b>:43(<module>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-4-81394220ed8b>:66(<module>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-4-81394220ed8b>:73(<module>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-5-c2b4fd6ccfde>:3(<module>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-5-c2b4fd6ccfde>:6(<module>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-5-c2b4fd6ccfde>:16(<module>)
#         1    0.000    0.000    0.001    0.001 <ipython-input-15-60fd33d0f73d>:12(<module>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-13-711c285a935b>:13(<module>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-13-711c285a935b>:18(<module>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-13-711c285a935b>:14(<module>)
